# %% [markdown]
# # INFO-4604/5604 HW2: Linear Classification
#
# ### Solution by: *YOUR NAME* (and list any partners)

# %% [markdown]
# ## Assignment overview
#
# News agencies, governments and corporations sometimes track social media during natural disasters to try to monitor unfolding events. But because no single person or group of people can read all available Twitter data, organizations may turn to natural language processing methods to try and understand what is happening as disasters unfold.
#
# While this approach is powerful, inferring events from NLP can be tricky. For instance, say a person [tweets](https://twitter.com/AnyOtherAnnaK/status/629195955506708480) that "LOOK AT THE SKY LAST NIGHT IT WAS ABLAZE." This tweet includes the word "ablaze", which may signal to a computer that there is an unfolding disaster. However, in this particular case, the person is speaking metaphorically. A simple computer system using keywords (e.g. ablaze) might be fooled into thinking the tweet is reporting an actual fire.
#
# In this assignment, you will predict if a given tweet actually refers to a natural disaster. This exercise is motivated by real-world disaster monitoring systems, and can help you to gain practice with supervised binary classification and natural language processing.
#
# __Note__: This dataset originally comes from [Kaggle](https://www.kaggle.com/c/nlp-getting-started/overview). But it has been modified for this problem set. Information about the data from this problem set that you find on Kaggle will almost certainly be wrong.
#
# ### What to hand in
#
# You will submit the assignment on Canvas. Submit a single Jupyter notebook named `hw2lastname.ipynb`, where lastname is replaced with your last name. **Please also submit a PDF or HTML version of your notebook to Canvas**.
#
# Please clearly mark all deliverables. You are encouraged to create additional cells in whatever way makes the presentation more organized and easy to follow. You are allowed to import additional Python libraries.
#
# ### Submission policies
#
# - **Collaboration:** You are allowed to work with one partner. You are still expected to write up your own solution. Each individual must turn in their own submission, and list your collaborators after your name.
# - **Late submissions:** Each student may use up to 5 late days over the semester. You have late days, not late hours. This means that if your submission is late by any amount of time past the deadline, then this will use up a late day. If it is late by any amount beyond 24 hours past the deadline, then this will use a second late, and so on. Once you have used up all late days, late assignments will be given at most 80% credit after one day and 60% credit after two days.

# %% [markdown]
# ## Getting started
#
# In this assignment, you will experiment with perceptron and logistic regression in `sklearn`. Much of the code has already been written for you. We will use a class called `SGDClassifier` (which you should read about in the [sklearn documentation](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html)), which  implements stochastic gradient descent (SGD) for a variety of loss functions, including both perceptron and logistic regression, so this will be a way to easily move between the two classifiers.
#
# The code below will load the datasets. There are two data collections: the "training" data, which contains the tweets that you will use for training the classifiers, and the "testing" data, which are tweets that you will use to measure the classifier accuracy. The test tweets are instances the classifier has never seen before, so they are a good way to see how the classifier will behave on data it hasn't seen before. However, we still know the labels of the test tweets, so we can measure the accuracy.
#
# For this problem, we will use what are called "bag of words" features, which are commonly used when doing classification with text. Each feature is a word, and the value of a feature for a particular tweet is number of times the word appears in the tweet (with value $0$ if the word does not appear in the tweet).
#
# A note on labels: **If `Y_train` or `Y_test` are 1 this means the tweet refers to a real disaster; if the values are 0, it means the tweet does not refer to a real disaster**
#
# Run the block of code below to load the data. You don't need to do anything yet. Move on to "Problem 1" next.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

df_train = pd.read_csv('train.csv')

Y_train = df_train["target"]
text_train = df_train["text"]

vec = CountVectorizer()
X_train = vec.fit_transform(text_train)
feature_names = np.asarray(vec.get_feature_names())

df_test = pd.read_csv('test.csv')
Y_test = df_test["target"]
text_test = df_test["text"]

X_test = vec.transform(text_test)

# %% [markdown]
# ## Problem 1: Understand the data [3 points]
#
# Before doing anything else, take time to understand the code above.
#
# The variables `df_train` and `df_test` are dataframes that store the training (and testing) datasets, which are contained in comma-separated files where the first column is the label and the second column is the text of the tweet.
#
# The [`CountVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) class converts the raw text into a bag-of-words into a feature vector representation that `sklearn` can use.
#
# You should print out the values of the variables and write any other code needed to answer the following questions.
#
# #### Deliverable 1.1
#
# How many training instances are in the dataset? How many test instances?
#
# [your answer here]
#
# #### Deliverable 1.2
#
# How many features are in the training data?
#
# [your answer here]
#
# #### Deliverable 1.3
#
# What is the distribution of labels in the training data? That is, what percentage of instances are about actual disasters?
#
# [your answer here]

# %% [markdown]
# ## Problem 2: Perceptron [3 points]
#
# The code below trains an [`SGDClassifier`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html) using the perceptron loss, then it measures the accuracy of the classifier on the test data, using `sklearn`'s [`accuracy_score`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html) function.
#
# The `fit` function trains the classifier. The feature weights are stored in the `coef_` variable after training. The `predict` function of the trained `SGDClassifier` outputs the predicted label for a given instance or list of instances.
#
# Additionally, this code displays the features and their weights in sorted order, which you may want to examine to understand what the classifier is learning. In general, in binary classification, the 0 class is considered the "negative" class.
#
# There are 3 keyword arguments that have been added to the code below. It is important you keep the same values of these arguments whenever you create an `SGDClassifier` instance in this assignment so that you get consistent results. They are:
#
# - `max_iter` is one of the stopping criteria, which is the maximum number of iterations/epochs the algorithm will run for.
#
# - `tol` is the other stopping criterion, which is how small the difference between the current loss and previous loss should be before stopping.
#
# - `random_state` is a seed for pseudorandom number generation. The algorithm uses randomness in the way the training data are sorted, which will affect the solution that is learned, and even the accuracy of that solution.
#
# Note: *Wait a minute $-$ in class we learned that the loss function is convex, so the algorithm will find the same minimum regardless of how it is trained. Why is there random variation in the output? The reason is that even though there is only one minimum value of the loss, there may be different weights that result in the same loss, so randomness is a matter of tie-breaking. What's more, while different weights may have the same loss, they could lead to different classification accuracies, because the loss function is not the same as accuracy. (Unless accuracy was your loss function... which is possible, but uncommon because it turns out to be a difficult function to optimize.)
# Note that different computers may still give different answers, despite keeping these settings the same, because of how pseudorandom numbers are generated with different operating systems and Python environments.*
#
# To begin, run the code in the cell below without modification.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, precision_score

classifier = SGDClassifier(loss='perceptron', max_iter=1000, tol=1.0e-12, random_state=123, eta0=100)
classifier.fit(X_train, Y_train)

print("Number of SGD iterations: %d" % classifier.n_iter_)
print("Training accuracy: %0.6f" % accuracy_score(Y_train, classifier.predict(X_train)))
print("Testing accuracy: %0.6f" % accuracy_score(Y_test, classifier.predict(X_test)))

print("\nFeature weights:")
args = np.argsort(classifier.coef_[0])
for a in args:
    print(" %s: %0.4f" % (feature_names[a], classifier.coef_[0][a]))
# Out:
# Number of SGD iterations: 35
# Training accuracy: 0.987908
# Testing accuracy: 0.781648
#
# Feature weights:
#  zy3hpdjnwg: -0.7900
#  qzlpfhpwdo: -0.6970
#  better: -0.5112
#  f7wqpcekg2: -0.5112
#  sun: -0.5112
#  t5trhjuau0: -0.5112
#  august: -0.4647
#  seat: -0.4647
#  permanently: -0.4647
#  desire: -0.4647
#  hrqcjdovjz: -0.4647
#  qzqc8wwwcn: -0.4647
#  poll: -0.4647
#  appears: -0.4182
#  move: -0.4182
#  full: -0.4182
#  3yu26v19zh: -0.4182
#  dlaub2nvtn: -0.4182
#  jobs: -0.4182
#  6gldwx71da: -0.4182
#  scared: -0.4182
#  song: -0.4182
#  themselves: -0.3717
#  used: -0.3717
#  greenlacey: -0.3717
#  booksbyroger: -0.3717
#  l9mb2j5pxg: -0.3717
#  myself: -0.3717
#  zdj2hyf6ro: -0.3717
#  wrong: -0.3717
#  bags: -0.3717
#  lot: -0.3717
#  hands: -0.3717
#  show: -0.3717
#  x8moyevjsj: -0.3717
#  m5djllxozp: -0.3717
#  nzrwddlntp: -0.3717
#  market: -0.3717
#  mickinyman: -0.3717
#  theatlantic: -0.3717
#  esemjrn5cc: -0.3717
#  lets: -0.3717
#  ruin: -0.3717
#  jlczidz7vu: -0.3717
#  bejftygjil: -0.3717
#  best: -0.3717
#  long: -0.3717
#  book: -0.3717
#  wackoes: -0.3717
#  exited: -0.3717
#  b2yvlmpepr: -0.3717
#  nowplaying: -0.3253
#  remove: -0.3253
#  nice: -0.3253
#  let: -0.3253
#  aren: -0.3253
#  future: -0.3253
#  romance: -0.3253
#  australia: -0.3253
#  tbqsqtmqv4: -0.3253
#  finally: -0.3253
#  stone: -0.3253
#  career: -0.3253
#  sit: -0.3253
#  fact: -0.3253
#  online: -0.3253
#  bcdp4gkoka: -0.3253
#  sww0qsmxvm: -0.3253
#  eatfro3d5x: -0.3253
#  cat: -0.3253
#  ancient: -0.3253
#  gave: -0.3253
#  2wvmij5sa4: -0.3253
#  perfect: -0.3253
#  pb2n77nskz: -0.3253
#  mayonnaise: -0.3253
#  steps: -0.3253
#  spilt: -0.3253
#  put: -0.3253
#  wished: -0.3253
#  agony: -0.3253
#  cake: -0.3253
#  clinton: -0.3253
#  mode: -0.3253
#  pile: -0.3253
#  join: -0.3253
#  y0kbyy8nce: -0.3253
#  7npbfrzejl: -0.3253
#  such: -0.3253
#  gloriavelez: -0.3253
#  impact: -0.3253
#  gexhzu1vk8: -0.3253
#  cufgvupkzi: -0.3253
#  education: -0.3253
#  super: -0.3253
#  5zdbtktww7: -0.3253
#  ebay: -0.3253
#  hero: -0.3253
#  tribal: -0.3253
#  top: -0.3253
#  love: -0.2788
#  somebody: -0.2788
#  jupiter: -0.2788
#  larger: -0.2788
#  gg: -0.2788
#  trying: -0.2788
#  pumxlvlsgm: -0.2788
#  gxgm1t3w0j: -0.2788
#  elation: -0.2788
#  vzod7qfflv: -0.2788
#  qbdryxsglc: -0.2788
#  games: -0.2788
#  growing: -0.2788
#  presence: -0.2788
#  many: -0.2788
#  pay: -0.2788
#  blue: -0.2788
#  johndcgow: -0.2788
#  real: -0.2788
#  postponed: -0.2788
#  learn: -0.2788
#  heartache: -0.2788
#  jhupogbvs8: -0.2788
#  statistically: -0.2788
#  gunning: -0.2788
#  fnmje8gf7m: -0.2788
#  nye8ae2ifr: -0.2788
#  writebothfists: -0.2788
#  ago: -0.2788
#  mskn6d3ekh: -0.2788
#  secret: -0.2788
#  godslove: -0.2788
#  5cwuylnfum: -0.2788
#  1tyyqfz13d: -0.2788
#  thanku: -0.2788
#  6aqrnankfd: -0.2788
#  mzmandilynn: -0.2788
#  9lyx7zmthe: -0.2788
#  5pbc96rtmj: -0.2788
#  louis: -0.2788
#  stroke: -0.2788
#  network: -0.2788
#  entertainment: -0.2788
#  corleonedaboss: -0.2788
#  significance: -0.2788
#  stereo: -0.2788
#  load: -0.2788
#  shedding: -0.2788
#  lil: -0.2788
#  stock: -0.2788
#  partially: -0.2788
#  lucky: -0.2788
#  missleylaha: -0.2788
#  holding: -0.2788
#  cia: -0.2788
#  hahahaha: -0.2788
#  experience: -0.2788
#  james: -0.2788
#  standwithpp: -0.2788
#  ashley: -0.2788
#  bite: -0.2788
#  miss: -0.2788
#  friend: -0.2788
#  welcome: -0.2788
#  never: -0.2788
#  lhpgxc4b8j: -0.2788
#  forbes: -0.2788
#  nikoniko12022: -0.2788
#  contact: -0.2788
#  trip: -0.2788
#  matako_3: -0.2788
#  quick: -0.2788
#  unless: -0.2788
#  architect: -0.2788
#  emmerdale: -0.2788
#  same: -0.2788
#  reasons: -0.2788
#  epicentre: -0.2788
#  adam: -0.2788
#  wonder: -0.2788
#  vet: -0.2788
#  weighs: -0.2788
#  lethal: -0.2788
#  quiz: -0.2788
#  2005: -0.2788
#  self: -0.2788
#  6ysbcsszys: -0.2788
#  head: -0.2788
#  broke: -0.2788
#  posters: -0.2788
#  realize: -0.2788
#  gzekqwzijq: -0.2788
#  dope: -0.2788
#  zombie: -0.2788
#  becarefulharry: -0.2788
#  wired: -0.2788
#  dey: -0.2788
#  daddy: -0.2788
#  writing: -0.2788
#  pregnant: -0.2788
#  complete: -0.2788
#  pre: -0.2788
#  sayzt2oagm: -0.2788
#  jeb: -0.2788
#  wedding: -0.2788
#  emotional: -0.2788
#  4i0kz2akly: -0.2788
#  albums: -0.2788
#  common: -0.2788
#  cook: -0.2788
#  also: -0.2788
#  eyes: -0.2788
#  0fekgyby5f: -0.2788
#  your: -0.2323
#  you: -0.2323
#  music: -0.2323
#  video: -0.2323
#  keep: -0.2323
#  phone: -0.2323
#  cityofmemphis: -0.2323
#  dying: -0.2323
#  stronger: -0.2323
#  nasty: -0.2323
#  every: -0.2323
#  straight: -0.2323
#  quote: -0.2323
#  startup: -0.2323
#  mcdonalds: -0.2323
#  entire: -0.2323
#  play: -0.2323
#  wvtpuryx63: -0.2323
#  trump: -0.2323
#  talk: -0.2323
#  harrystyles: -0.2323
#  cern: -0.2323
#  oo: -0.2323
#  guns: -0.2323
#  harrybecareful: -0.2323
#  p4huqundqi: -0.2323
#  justinbieber: -0.2323
#  change: -0.2323
#  seeing: -0.2323
#  skies: -0.2323
#  c9jnxz3dxc: -0.2323
#  crack: -0.2323
#  lovely: -0.2323
#  2oroyunym2: -0.2323
#  arts: -0.2323
#  åêm: -0.2323
#  h6ngsw9a5b: -0.2323
#  atleast: -0.2323
#  jd7rik7fx0: -0.2323
#  hurt: -0.2323
#  gqskwqzuul: -0.2323
#  compete: -0.2323
#  wont: -0.2323
#  go0pkrfzmf: -0.2323
#  decided: -0.2323
#  diamond: -0.2323
#  transporta: -0.2323
#  rfp: -0.2323
#  innovative: -0.2323
#  z3nevglufm: -0.2323
#  450: -0.2323
#  fresno: -0.2323
#  8gtrvece1n: -0.2323
#  anti: -0.2323
#  nature: -0.2323
#  jbrk8zsry6: -0.2323
#  theadvocatemag: -0.2323
#  lmao: -0.2323
#  attempted: -0.2323
#  ubfr1urafc: -0.2323
#  alnv51d95x: -0.2323
#  current: -0.2323
#  mis0rjxuir: -0.2323
#  unconfirmed: -0.2323
#  neighbour: -0.2323
#  xd: -0.2323
#  capture: -0.2323
#  17egmlni80: -0.2323
#  truths: -0.2323
#  origin: -0.2323
#  x1411: -0.2323
#  wfseaobato: -0.2323
#  headlines: -0.2323
#  s4pnihjqx7: -0.2323
#  flag: -0.2323
#  felt: -0.2323
#  mind: -0.2323
#  sifting: -0.2323
#  twoptwips: -0.2323
#  blew: -0.2323
#  aftershock: -0.2323
#  hasn: -0.2323
#  financial: -0.2323
#  doe: -0.2323
#  republican: -0.2323
#  fucoqhclad: -0.2323
#  easy: -0.2323
#  party: -0.2323
#  air: -0.2323
#  mayhem: -0.2323
#  blamed: -0.2323
#  throughout: -0.2323
#  adorableappple: -0.2323
#  tried: -0.2323
#  britain: -0.2323
#  scout: -0.2323
#  hxdg254dho: -0.2323
#  khd99oz7u3: -0.2323
#  mmda: -0.2323
#  portaloos: -0.2323
#  po: -0.2323
#  53: -0.2323
#  defendbutera: -0.2323
#  sentient: -0.2323
#  paper: -0.2323
#  rea: -0.2323
#  02: -0.2323
#  buy: -0.2323
#  fhi4qbpwfh: -0.2323
#  hqdczzdmbn: -0.2323
#  fredolsencruise: -0.2323
#  water: -0.2323
#  ndgpwyxu6h: -0.2323
#  dolphins: -0.2323
#  itinerary: -0.2323
#  bridges: -0.2323
#  ibx3cragtt: -0.2323
#  3tssxphufe: -0.2323
#  hobbit: -0.2323
#  kimkardashian: -0.2323
#  upheaval: -0.2323
#  hundred: -0.2323
#  stage: -0.2323
#  grade: -0.2323
#  ticket: -0.2323
#  challenges: -0.2323
#  arizona: -0.2323
#  tongue: -0.2323
#  8jcyxhq1az: -0.2323
#  maid: -0.2323
#  disney: -0.2323
#  dh30000: -0.2323
#  y35qtvdsoh: -0.2323
#  chemical: -0.2323
#  qhujajctr5: -0.2323
#  3gz5zqqthe: -0.2323
#  asked: -0.2323
#  opening: -0.2323
#  ship: -0.2323
#  tv: -0.2323
#  shira: -0.2323
#  practice: -0.2323
#  banki: -0.2323
#  write: -0.2323
#  irqj3zkcuz: -0.2323
#  nxttd9nrux: -0.2323
#  startups: -0.2323
#  tahoe: -0.2323
#  diving: -0.2323
#  devybnvxgq: -0.2323
#  soaking: -0.2323
#  todayng: -0.2323
#  mother: -0.2323
#  epic: -0.2323
#  aatt5amnmd: -0.2323
#  art: -0.2323
#  whippenz: -0.2323
#  harry: -0.2323
#  facebook: -0.2323
#  deep: -0.2323
#  sale: -0.2323
#  dorret: -0.2323
#  capacity: -0.2323
#  deluge: -0.2323
#  filipino: -0.2323
#  doors: -0.2323
#  imilsfxntf: -0.2323
#  broad: -0.2323
#  runs: -0.2323
#  fan: -0.2323
#  bring: -0.2323
#  blowin: -0.2323
#  cus: -0.2323
#  away: -0.2323
#  hes: -0.2323
#  queenwendy_: -0.2323
#  spend: -0.2323
#  loved: -0.2323
#  everything: -0.2323
#  open: -0.2323
#  kotolily_: -0.2323
#  favorite: -0.2323
#  rtfirzcpoc: -0.2323
#  flat: -0.2323
#  gay: -0.2323
#  fun: -0.2323
#  terrible: -0.2323
#  prophetmuhammad: -0.2323
#  madinah: -0.2323
#  lady: -0.2323
#  gotten: -0.2323
#  ball: -0.2323
#  without: -0.2323
#  sure: -0.2323
#  national: -0.2323
#  blazing: -0.2323
#  four: -0.1859
#  rubber: -0.1859
#  g62txymzbv: -0.1859
#  sitting: -0.1859
#  protest: -0.1859
#  um3wtl5r7k: -0.1859
#  2lqyxzq5dn: -0.1859
#  fans: -0.1859
#  person: -0.1859
#  feminist: -0.1859
#  version: -0.1859
#  reaching: -0.1859
#  crowned: -0.1859
#  tends: -0.1859
#  sides: -0.1859
#  circus: -0.1859
#  00: -0.1859
#  exactly: -0.1859
#  hall: -0.1859
#  wowo: -0.1859
#  destroying: -0.1859
#  schools: -0.1859
#  meteors: -0.1859
#  overload: -0.1859
#  traffic: -0.1859
#  plan: -0.1859
#  bass: -0.1859
#  ur: -0.1859
#  risk: -0.1859
#  hi: -0.1859
#  x1441: -0.1859
#  kabwandi_: -0.1859
#  blight: -0.1859
#  ugly: -0.1859
#  beyond: -0.1859
#  buried: -0.1859
#  drvox: -0.1859
#  angry: -0.1859
#  agw: -0.1859
#  forward: -0.1859
#  tarmineta3: -0.1859
#  crabbycale: -0.1859
#  turns: -0.1859
#  she: -0.1859
#  seen: -0.1859
#  alllivesmatter: -0.1859
#  shawie17shawie: -0.1859
#  vwcf3slkrw: -0.1859
#  ieksnfsby7: -0.1859
#  cinema: -0.1859
#  wpri: -0.1859
#  laughing: -0.1859
#  equal: -0.1859
#  k_matako_bot: -0.1859
#  roanoketimes: -0.1859
#  mood: -0.1859
#  wgasoencwc: -0.1859
#  cadzxagmsi: -0.1859
#  35jyap0ul9: -0.1859
#  misery: -0.1859
#  srruqfffr6: -0.1859
#  yebxxarybf: -0.1859
#  regional: -0.1859
#  lmumzkltln: -0.1859
#  kooks: -0.1859
#  waking: -0.1859
#  vitalvegas: -0.1859
#  stool: -0.1859
#  kosciusko: -0.1859
#  reined: -0.1859
#  lasvegaslocally: -0.1859
#  drinks: -0.1859
#  earbuds: -0.1859
#  heights: -0.1859
#  mins: -0.1859
#  nearby: -0.1859
#  penn: -0.1859
#  knows: -0.1859
#  ei8qqhregz: -0.1859
#  hair: -0.1859
#  inject: -0.1859
#  ccot: -0.1859
#  saturday: -0.1859
#  piling: -0.1859
#  trailer: -0.1859
#  needle: -0.1859
#  anderson: -0.1859
#  drops: -0.1859
#  veins: -0.1859
#  e65v80fcus: -0.1859
#  coping: -0.1859
#  happy: -0.1859
#  badges: -0.1859
#  economies: -0.1859
#  waved: -0.1859
#  fat: -0.1859
#  misled: -0.1859
#  rv: -0.1859
#  offers: -0.1859
#  size: -0.1859
#  victorious: -0.1859
#  finn: -0.1859
#  u30n3ffx8y: -0.1859
#  nostalgia: -0.1859
#  chrissie: -0.1859
#  tracking: -0.1859
#  thomas: -0.1859
#  jbpgkgowsi: -0.1859
#  sought: -0.1859
#  jp2qlrunjj: -0.1859
#  button: -0.1859
#  dirt: -0.1859
#  chief__cg: -0.1859
#  episode: -0.1859
#  guest: -0.1859
#  bzdfznkvog: -0.1859
#  supervisor: -0.1859
#  row: -0.1859
#  causing: -0.1859
#  erhdh37rdh: -0.1859
#  porridge: -0.1859
#  present: -0.1859
#  202: -0.1859
#  working: -0.1859
#  skyline: -0.1859
#  actavis: -0.1859
#  to0bpieyms: -0.1859
#  soundcloud: -0.1859
#  smash: -0.1859
#  cramming: -0.1859
#  muscle: -0.1859
#  pockets: -0.1859
#  chocolate: -0.1859
#  nightmare: -0.1859
#  mail: -0.1859
#  grills: -0.1859
#  false: -0.1859
#  modelbubbles: -0.1859
#  spain: -0.1859
#  truth: -0.1859
#  looked: -0.1859
#  bear: -0.1859
#  lake: -0.1859
#  psa: -0.1859
#  mido: -0.1859
#  wwi: -0.1859
#  bid: -0.1859
#  qumce7w2ty: -0.1859
#  ktkg2sdhhl: -0.1859
#  ww1: -0.1859
#  impressive: -0.1859
#  retail: -0.1859
#  pertains: -0.1859
#  whimsy: -0.1859
#  voting: -0.1859
#  thnexicgqe: -0.1859
#  covered: -0.1859
#  j5onxfwlao: -0.1859
#  priceless: -0.1859
#  criminal: -0.1859
#  folk: -0.1859
#  mohammed: -0.1859
#  built: -0.1859
#  worldoil: -0.1859
#  mkx: -0.1859
#  management: -0.1859
#  thurs: -0.1859
#  chevy: -0.1859
#  kqvevuutdj: -0.1859
#  subscription: -0.1859
#  aust: -0.1859
#  defend: -0.1859
#  babes: -0.1859
#  uploading: -0.1859
#  myhohvrhil: -0.1859
#  search: -0.1859
#  bicentennial: -0.1859
#  awakenings: -0.1859
#  igwstttkwk: -0.1859
#  radychildrens: -0.1859
#  ive: -0.1859
#  u2njpor39k: -0.1859
#  åè: -0.1859
#  tm5hthfdo0: -0.1859
#  infectious: -0.1859
#  outage: -0.1859
#  smoochy: -0.1859
#  clips: -0.1859
#  traumatised: -0.1859
#  hop: -0.1859
#  zero: -0.1859
#  warned: -0.1859
#  30pm: -0.1859
#  huh: -0.1859
#  square: -0.1859
#  baseball: -0.1859
#  absolutely: -0.1859
#  xqiadg9h2w: -0.1859
#  grey: -0.1859
#  insurer: -0.1859
#  sunny: -0.1859
#  kenya: -0.1859
#  arrestpastornganga: -0.1859
#  leaves: -0.1859
#  hotel: -0.1859
#  ypeelmjdzy: -0.1859
#  either: -0.1859
#  vacant: -0.1859
#  remembering: -0.1859
#  booktubeathon: -0.1859
#  playoffs: -0.1859
#  supernatural: -0.1859
#  treescape: -0.1859
#  jhscgda2g8: -0.1859
#  whales: -0.1859
#  e2dbcpwd9u: -0.1859
#  fascinating: -0.1859
#  maybe: -0.1859
#  propaganda: -0.1859
#  republicans: -0.1859
#  umzkc9azwd: -0.1859
#  fail: -0.1859
#  mmmmmm: -0.1859
#  gd: -0.1859
#  o784: -0.1859
#  oooh: -0.1859
#  hvyxehxbmq: -0.1859
#  oooooohhhh: -0.1859
#  seriously: -0.1859
#  ooh: -0.1859
#  zagbmlsf4h: -0.1859
#  commercial: -0.1859
#  evil: -0.1859
#  åç: -0.1859
#  testing: -0.1859
#  gbctmhx7pw: -0.1859
#  skarletan: -0.1859
#  swell: -0.1859
#  anyway: -0.1859
#  vest: -0.1859
#  kijima_matako: -0.1859
#  foxnewsinsider: -0.1859
#  tlc: -0.1859
#  asap: -0.1859
#  entering: -0.1859
#  brothers: -0.1859
#  conversations: -0.1859
#  oia5fxi4gm: -0.1859
#  movies: -0.1859
#  hang: -0.1859
#  ls: -0.1859
#  abbott: -0.1859
#  yg32yb2jdy: -0.1859
#  touch: -0.1859
#  surprised: -0.1859
#  ohbv7yvtl5: -0.1859
#  alcohol: -0.1859
#  ymuti3nd9r: -0.1859
#  rockbottomradfm: -0.1859
#  pledge: -0.1859
#  rescuing: -0.1859
#  allegiance: -0.1859
#  automation: -0.1859
#  joy: -0.1859
#  barbi_twins: -0.1859
#  rome: -0.1859
#  indyfest: -0.1859
#  di5arr6hq6: -0.1859
#  yl67dkf4tb: -0.1859
#  lover: -0.1859
#  fran: -0.1859
#  milwaukee: -0.1859
#  jay: -0.1859
#  electrocute: -0.1859
#  threats: -0.1859
#  gold: -0.1859
#  nap: -0.1859
#  trusting: -0.1859
#  ryleedowns02: -0.1859
#  nevaehburton33: -0.1859
#  ykltfj1fnc: -0.1859
#  summer2k15: -0.1859
#  zabadani: -0.1859
#  kindle: -0.1859
#  6lojoorouk: -0.1859
#  moon: -0.1859
#  success: -0.1859
#  freefromwolves: -0.1859
#  scraped: -0.1859
#  dance: -0.1859
#  danny: -0.1859
#  card: -0.1859
#  commodity: -0.1859
#  hiring: -0.1859
#  election: -0.1859
#  4hngtkdqmv: -0.1859
#  looting: -0.1859
#  thrones: -0.1859
#  7ieiz619h0: -0.1859
#  watsmxytva: -0.1859
#  tonto: -0.1859
#  stuart: -0.1859
#  cupcake: -0.1859
#  ucawg59ulj: -0.1859
#  sjicbhzfo4: -0.1859
#  enqdfbjump: -0.1859
#  slicker: -0.1859
#  tfeanwhh2h: -0.1859
#  medium: -0.1859
#  ps: -0.1859
#  mary: -0.1859
#  finishing: -0.1859
#  brunt: -0.1859
#  title: -0.1859
#  grayed: -0.1859
#  nwspocatello: -0.1859
#  interspersed: -0.1859
#  gllawb2fsk: -0.1859
#  articles: -0.1859
#  member: -0.1859
#  create: -0.1859
#  3kaafuoztc: -0.1859
#  wearing: -0.1859
#  elsa: -0.1859
#  pocket: -0.1859
#  nm: -0.1859
#  snowy: -0.1859
#  c5u9qsysej: -0.1859
#  reckless: -0.1859
#  shares: -0.1859
#  masochisticmage: -0.1859
#  taste: -0.1859
#  sudden: -0.1859
#  our_mother_mary: -0.1859
#  bet: -0.1859
#  frkodestuk: -0.1859
#  screw: -0.1859
#  shall: -0.1859
#  challenging: -0.1859
#  handle: -0.1859
#  satan: -0.1859
#  jf5ft5cq9j: -0.1859
#  21: -0.1859
#  phoenix: -0.1859
#  news3lv: -0.1859
#  vibrates: -0.1859
#  notifications: -0.1859
#  reap: -0.1859
#  exdbcx4gcr: -0.1859
#  throw: -0.1859
#  roi2nsmejj: -0.1859
#  slightest: -0.1859
#  stirring: -0.1859
#  yduixefipe: -0.1859
#  elbow: -0.1859
#  nsfw: -0.1859
#  hold: -0.1859
#  amazing: -0.1859
#  3tj8zjin21: -0.1859
#  books: -0.1859
#  lxtjc87kls: -0.1859
#  feeding: -0.1859
#  ac: -0.1859
#  û_: -0.1859
#  heebsterrr_: -0.1859
#  abomination: -0.1859
#  bigamist: -0.1859
#  xgkyvf9t4f: -0.1859
#  holdin: -0.1859
#  lamha: -0.1859
#  markets: -0.1859
#  rockin: -0.1859
#  wrqf6u55hh: -0.1859
#  tough: -0.1859
#  p93s2rfhx6: -0.1859
#  yay: -0.1859
#  gix1gaynxz: -0.1859
#  qadufo8zxg: -0.1859
#  probably: -0.1859
#  o6onsjhcsd: -0.1859
#  2pimg9bice: -0.1859
#  meinlcymbals: -0.1859
#  p2: -0.1859
#  c5ggszugw1: -0.1859
#  local: -0.1859
#  bar: -0.1859
#  makes: -0.1859
#  new: -0.1859
#  6aug: -0.1859
#  republic: -0.1859
#  heart: -0.1859
#  moment: -0.1859
#  obliteration: -0.1859
#  ducks: -0.1859
#  stamp: -0.1859
#  planned: -0.1859
#  ladies: -0.1859
#  save: -0.1859
#  cleared: -0.1859
#  movie: -0.1859
#  everyone: -0.1859
#  use: -0.1394
#  who: -0.1394
#  he: -0.1394
#  earth: -0.1394
#  god: -0.1394
#  chewing: -0.1394
#  prevent: -0.1394
#  tent: -0.1394
#  find: -0.1394
#  middle: -0.1394
#  values: -0.1394
#  jbxbi93clu: -0.1394
#  skynet: -0.1394
#  i5cdtd8ftj: -0.1394
#  73umw2igrz: -0.1394
#  tokteacher: -0.1394
#  david_hurn: -0.1394
#  mjbiuvbmo6: -0.1394
#  spot: -0.1394
#  july: -0.1394
#  staff: -0.1394
#  feels: -0.1394
#  edit: -0.1394
#  latechwatch: -0.1394
#  flowers: -0.1394
#  r3pddjpiee: -0.1394
#  sexist: -0.1394
#  possible: -0.1394
#  liberal: -0.1394
#  falphil: -0.1394
#  traditional: -0.1394
#  compassion: -0.1394
#  ended: -0.1394
#  ep016: -0.1394
#  dnbheaven: -0.1394
#  ejkrf8n8a8: -0.1394
#  dfr: -0.1394
#  register: -0.1394
#  sphwe6wfi5: -0.1394
#  baby: -0.1394
#  monthly: -0.1394
#  morehouse64: -0.1394
#  w2kvscbtlp: -0.1394
#  2ns5tfnxpa: -0.1394
#  tn8o00nrlp: -0.1394
#  ethical: -0.1394
#  relevance: -0.1394
#  ty: -0.1394
#  celebrations: -0.1394
#  navigating: -0.1394
#  hxtupra5bc: -0.1394
#  abused: -0.1394
#  dqxkjibbky: -0.1394
#  john: -0.1394
#  tuzacdwfqd: -0.1394
#  6hkca1dsna: -0.1394
#  clowns: -0.1394
#  i5k3vjicmg: -0.1394
#  mercy: -0.1394
#  cizjafnm4e: -0.1394
#  documentary: -0.1394
#  luck: -0.1394
#  yes: -0.1394
#  interviews: -0.1394
#  narrated: -0.1394
#  teacher: -0.1394
#  parter: -0.1394
#  netflix: -0.1394
#  jays: -0.1394
#  leafs: -0.1394
#  darude: -0.1394
#  painting: -0.1394
#  gbbo: -0.1394
#  denial: -0.1394
#  downright: -0.1394
#  app: -0.1394
#  economic: -0.1394
#  safari: -0.1394
#  ykdsp0nrdq: -0.1394
#  balanced: -0.1394
#  balance: -0.1394
#  heavenly: -0.1394
#  linkury: -0.1394
#  bc: -0.1394
#  whedonesque: -0.1394
#  scourge: -0.1394
#  browser: -0.1394
#  fanged: -0.1394
#  q0jhdcu6ly: -0.1394
#  cop: -0.1394
#  reopen: -0.1394
#  ibsvy2r3ph: -0.1394
#  wants: -0.1394
#  george: -0.1394
#  cared: -0.1394
#  idc: -0.1394
#  wilden: -0.1394
#  elianaraquel: -0.1394
#  having: -0.1394
#  china: -0.1394
#  thing: -0.1394
#  kiwi_karyn: -0.1394
#  hpvodud7ip: -0.1394
#  deals: -0.1394
#  playing: -0.1394
#  allegations: -0.1394
#  leaving: -0.1394
#  status: -0.1394
#  ocd: -0.1394
#  scwx: -0.1394
#  intrigued: -0.1394
#  remembered: -0.1394
#  2y9dnp5vtg: -0.1394
#  grlxurko8d: -0.1394
#  whitewalkers: -0.1394
#  article: -0.1394
#  6xul6dcosh: -0.1394
#  i0tvl15coz: -0.1394
#  friends: -0.1394
#  waimea: -0.1394
#  nasasolarsystem: -0.1394
#  czdw8oowa2: -0.1394
#  store: -0.1394
#  igtxhapo0k: -0.1394
#  surfers: -0.1394
#  flattened: -0.1394
#  basis: -0.1394
#  ems: -0.1394
#  dickheads: -0.1394
#  disappearance: -0.1394
#  apply: -0.1394
#  removing: -0.1394
#  fifa16: -0.1394
#  zqrcptlrum: -0.1394
#  manager: -0.1394
#  mnh6fxhodb: -0.1394
#  forsythe: -0.1394
#  uber: -0.1394
#  shoes: -0.1394
#  fkhanage: -0.1394
#  shad: -0.1394
#  series: -0.1394
#  pedestrian: -0.1394
#  shitton: -0.1394
#  shay: -0.1394
#  thinks: -0.1394
#  elevator: -0.1394
#  playthrough: -0.1394
#  special: -0.1394
#  wp6v1bhhoq: -0.1394
#  exclusively: -0.1394
#  noses: -0.1394
#  pick: -0.1394
#  trust: -0.1394
#  merycormier: -0.1394
#  cosima: -0.1394
#  connecto: -0.1394
#  magisters: -0.1394
#  repay: -0.1394
#  mortal: -0.1394
#  together: -0.1394
#  fuckin: -0.1394
#  warships: -0.1394
#  kombat: -0.1394
#  derby: -0.1394
#  gym: -0.1394
#  ahead: -0.1394
#  external: -0.1394
#  rise: -0.1394
#  tickets: -0.1394
#  forsure: -0.1394
#  uncle: -0.1394
#  hurts: -0.1394
#  drfriedencdc: -0.1394
#  emhub: -0.1394
#  qu8s89pvvt: -0.1394
#  infections: -0.1394
#  niv8x5tbe0: -0.1394
#  caesars: -0.1394
#  audiences: -0.1394
#  ugc: -0.1394
#  embraced: -0.1394
#  gzmoblsjxu: -0.1394
#  design: -0.1394
#  clip: -0.1394
#  adiossuperbacterias: -0.1394
#  5cgtqfk2ur: -0.1394
#  6mbpvwitxf: -0.1394
#  actively: -0.1394
#  final: -0.1394
#  v1mtr517ue: -0.1394
#  zyrzx6dfki: -0.1394
#  eytay: -0.1394
#  neur0sis: -0.1394
#  jqfcy9guqv: -0.1394
#  soaker: -0.1394
#  shift: -0.1394
#  hashtag: -0.1394
#  universe: -0.1394
#  vlnjnolnme: -0.1394
#  hrsfa8zuji: -0.1394
#  tn65puhfhw: -0.1394
#  if5rogfjri: -0.1394
#  king: -0.1394
#  society: -0.1394
#  browseråêhijacker: -0.1394
#  chill: -0.1394
#  squirrel: -0.1394
#  zachlowe_nba: -0.1394
#  investigate: -0.1394
#  darkness: -0.1394
#  annoying: -0.1394
#  yzzxxknism: -0.1394
#  courses: -0.1394
#  owners: -0.1394
#  alex: -0.1394
#  protect: -0.1394
#  bands: -0.1394
#  preston: -0.1394
#  pdkhbdg9ho: -0.1394
#  fylde: -0.1394
#  robinson: -0.1394
#  iconic: -0.1394
#  zzsee5hipm: -0.1394
#  jmd7zwksdm: -0.1394
#  ask: -0.1394
#  course: -0.1394
#  sanctions: -0.1394
#  disappearing: -0.1394
#  insult: -0.1394
#  derivatives: -0.1394
#  m8mvdspjp7: -0.1394
#  m2y9ym3if6: -0.1394
#  minute: -0.1394
#  latin: -0.1394
#  poverty: -0.1394
#  treatment: -0.1394
#  quadrillion: -0.1394
#  kf74o2mcsc: -0.1394
#  shouldn: -0.1394
#  lyj57pq3yx: -0.1394
#  katrina: -0.1394
#  hear: -0.1394
#  gajtugaui7: -0.1394
#  n2zhrchcgv: -0.1394
#  chains: -0.1394
#  hole: -0.1394
#  ghmmuj7gbe: -0.1394
#  argentina: -0.1394
#  saying: -0.1394
#  u9lvvlzhye: -0.1394
#  gbqtc7sp9c: -0.1394
#  spinningbot: -0.1394
#  dollars: -0.1394
#  gbay99: -0.1394
#  0blkwcupzq: -0.1394
#  blakeschmidt: -0.1394
#  hienshi: -0.1394
#  saddlebrooke: -0.1394
#  depth: -0.1394
#  united: -0.1394
#  wouldnt: -0.1394
#  holds: -0.1394
#  hxm8c8e33d: -0.1394
#  billionaires: -0.1394
#  languages: -0.1394
#  excuses: -0.1394
#  answer: -0.1394
#  jusreign: -0.1394
#  bonn1egreer: -0.1394
#  propelled: -0.1394
#  wb: -0.1394
#  crystal: -0.1394
#  mineral: -0.1394
#  30: -0.1394
#  secrets: -0.1394
#  stays: -0.1394
#  reshape: -0.1394
#  piles: -0.1394
#  hua: -0.1394
#  law: -0.1394
#  anyways: -0.1394
#  hip: -0.1394
#  reads: -0.1394
#  reshapes: -0.1394
#  ou_wbball: -0.1394
#  danielle: -0.1394
#  ztfead8gid: -0.1394
#  advice: -0.1394
#  project: -0.1394
#  flaws: -0.1394
#  biuey7buts: -0.1394
#  loads: -0.1394
#  armory: -0.1394
#  xvco7slxhw: -0.1394
#  dspws6hj8w: -0.1394
#  collaborating: -0.1394
#  martial: -0.1394
#  crap: -0.1394
#  pardon: -0.1394
#  worrying: -0.1394
#  fxux987vzx: -0.1394
#  paved: -0.1394
#  jwqybe4ep1: -0.1394
#  napviygkyk: -0.1394
#  nuys: -0.1394
#  fuck: -0.1394
#  jbvmgeg522: -0.1394
#  jackson: -0.1394
#  zqo6nuvytu: -0.1394
#  moorlandschmbr: -0.1394
#  circle: -0.1394
#  vannuyscouncil: -0.1394
#  mindless: -0.1394
#  francisunderwood: -0.1394
#  hoc: -0.1394
#  led: -0.1394
#  bhp: -0.1394
#  x6el3ysycn: -0.1394
#  liable: -0.1394
#  jitsu: -0.1394
#  hexagon: -0.1394
#  pillow: -0.1394
#  holiday: -0.1394
#  billiton: -0.1394
#  geysers: -0.1394
#  ûïnews: -0.1394
#  qqsmshaj3n: -0.1394
#  nne: -0.1394
#  forex: -0.1394
#  lnzi7o166y: -0.1394
#  dries: -0.1394
#  uungrqougn: -0.1394
#  tmpfwjpi6i: -0.1394
#  yelled: -0.1394
#  1km: -0.1394
#  weight: -0.1394
#  hqod6v6dnc: -0.1394
#  disco: -0.1394
#  choices: -0.1394
#  theemobrago: -0.1394
#  streaming: -0.1394
#  trading: -0.1394
#  laid: -0.1394
#  goin: -0.1394
#  mixtape: -0.1394
#  pztbqimpuw: -0.1394
#  xxj2b4jxrt: -0.1394
#  profit: -0.1394
#  bp6mfjhars: -0.1394
#  porn: -0.1394
#  sweet: -0.1394
#  yg6rj86bki: -0.1394
#  pe2r3ln16o: -0.1394
#  cnqae9foj6: -0.1394
#  r18autnlsd: -0.1394
#  oyy9mgw7hn: -0.1394
#  nrc: -0.1394
#  9gtylgxroe: -0.1394
#  nike: -0.1394
#  calhoun: -0.1394
#  darkest: -0.1394
#  soup: -0.1394
#  changed: -0.1394
#  excitement: -0.1394
#  joel: -0.1394
#  seemed: -0.1394
#  sel: -0.1394
#  selfies: -0.1394
#  vaca: -0.1394
#  loan: -0.1394
#  hinterestin: -0.1394
#  function: -0.1394
#  type: -0.1394
#  companies: -0.1394
#  loves: -0.1394
#  tag: -0.1394
#  dept: -0.1394
#  incase: -0.1394
#  bat: -0.1394
#  lego: -0.1394
#  handside: -0.1394
#  mama: -0.1394
#  snaymldiun: -0.1394
#  idiot: -0.1394
#  effort: -0.1394
#  faroeislands: -0.1394
#  invalid: -0.1394
#  v5gtunwohy: -0.1394
#  sjoeing76t: -0.1394
#  zimbabwe: -0.1394
#  among: -0.1394
#  film: -0.1394
#  revenge: -0.1394
#  cooking: -0.1394
#  ûïthe: -0.1394
#  twins: -0.1394
#  fort: -0.1394
#  color: -0.1394
#  recent: -0.1394
#  mental: -0.1394
#  rick: -0.1394
#  remainontop: -0.1394
#  all: -0.1394
#  todayhave: -0.1394
#  jax: -0.1394
#  babri: -0.1394
#  jolly_jinu: -0.1394
#  eating: -0.1394
#  omb3os54tn: -0.1394
#  royal: -0.1394
#  low: -0.1394
#  team: -0.1394
#  relax: -0.1394
#  isle: -0.1394
#  browsers: -0.1394
#  nqnwktrhsa: -0.1394
#  rbcinsurance: -0.1394
#  skardu: -0.1394
#  existant: -0.1394
#  website: -0.1394
#  machines: -0.1394
#  ohgod: -0.1394
#  theological: -0.1394
#  y4y8fcljed: -0.1394
#  justinejayyy: -0.1394
#  hermancranston: -0.1394
#  wvn6griypq: -0.1394
#  ice: -0.1394
#  hqewmreyso: -0.1394
#  ypvjgzqqqb: -0.1394
#  fitness: -0.1394
#  diet: -0.1394
#  kristindavis: -0.1394
#  ends: -0.1394
#  required: -0.1394
#  rest: -0.1394
#  leicester_merc: -0.1394
#  listening: -0.1394
#  rei3puwp84: -0.1394
#  accidentalprophecy: -0.1394
#  im2ad: -0.1394
#  freezing: -0.1394
#  kinda: -0.1394
#  xb1: -0.1394
#  ryobyqjfce: -0.1394
#  becoming: -0.1394
#  dystopian: -0.1394
#  advanced: -0.1394
#  likely: -0.1394
#  shaw: -0.1394
#  grizzly: -0.1394
#  band: -0.1394
#  dc: -0.1394
#  1017: -0.1394
#  gmail: -0.1394
#  guard: -0.1394
#  lw9o2kdk18: -0.1394
#  cancel: -0.1394
#  anna: -0.1394
#  x1434: -0.1394
#  generation: -0.1394
#  rec: -0.1394
#  efg8rth9rb: -0.1394
#  qamgvqafzc: -0.1394
#  ey: -0.1394
#  euro: -0.1394
#  obsessed: -0.1394
#  3ejl9lzlch: -0.1394
#  smug: -0.1394
#  enter: -0.1394
#  rudd: -0.1394
#  gateau: -0.1394
#  surface: -0.1394
#  church: -0.1394
#  tusky: -0.1394
#  irony: -0.1394
#  of3q75fgeu: -0.1394
#  words: -0.1394
#  _onlyftf: -0.1394
#  ants: -0.1394
#  cotton: -0.1394
#  robsimss: -0.1394
#  notes: -0.1394
#  mofanon: -0.1394
#  fish: -0.1394
#  dbu30obdxz: -0.1394
#  cantmisskid: -0.1394
#  beat: -0.1394
#  typing: -0.1394
#  bears: -0.1394
#  bangalore: -0.1394
#  retweet: -0.1394
#  xuhmj098lq: -0.1394
#  africaå: -0.1394
#  åèmgn: -0.1394
#  animals: -0.1394
#  skaausjpo4: -0.1394
#  aftershock_delo: -0.1394
#  longer: -0.1394
#  inviting: -0.1394
#  263789f4: -0.1394
#  wizkidayo: -0.1394
#  would: -0.1394
#  specimens: -0.1394
#  fdjuyvzmrv: -0.1394
#  eden: -0.1394
#  kmtwa3n1gf: -0.1394
#  2z2htdjqzd: -0.1394
#  cc: -0.1394
#  scuf: -0.1394
#  autumn: -0.1394
#  placed: -0.1394
#  oliviamiles01: -0.1394
#  pets: -0.1394
#  oi6cmagasi: -0.1394
#  tales: -0.1394
#  tee: -0.1394
#  nonucleariran: -0.1394
#  significant: -0.1394
#  wakeupflorida: -0.1394
#  farts: -0.1394
#  ageekyfangirl14: -0.1394
#  humor: -0.1394
#  z7phpjtqud: -0.1394
#  jebbush: -0.1394
#  badirandeal: -0.1394
#  trophyhunt: -0.1394
#  floridians: -0.1394
#  creates: -0.1394
#  å_: -0.1394
#  j5in8mexaj: -0.1394
#  t1mbw0ia3o: -0.1394
#  xe0ee1fzfh: -0.1394
#  matijwkzbh: -0.1394
#  clfa0py5lm: -0.1394
#  rebooting: -0.1394
#  adding: -0.1394
#  algtcn8baf: -0.1394
#  apart: -0.1394
#  2327564d: -0.1394
#  qfjjdxes7g: -0.1394
#  rice: -0.1394
#  hksbmijqz1: -0.1394
#  putting: -0.1394
#  alisonannyoung: -0.1394
#  behind: -0.1394
#  manly: -0.1394
#  politifiact: -0.1394
#  feelin: -0.1394
#  ending: -0.1394
#  pants: -0.1394
#  candylit: -0.1394
#  features: -0.1394
#  mat: -0.1394
#  ptsd: -0.1394
#  urs: -0.1394
#  stout: -0.1394
#  xizkjfff29: -0.1394
#  instagram: -0.1394
#  becomes: -0.1394
#  pun: -0.1394
#  tonne: -0.1394
#  mirage: -0.1394
#  cum: -0.1394
#  pancakes: -0.1394
#  edm: -0.1394
#  sarumi: -0.1394
#  jlput7va3s: -0.1394
#  till: -0.1394
#  inundation: -0.1394
#  concentration: -0.1394
#  fe: -0.1394
#  6uhih9pbru: -0.1394
#  sarcasm: -0.1394
#  camps: -0.1394
#  itsnasb: -0.1394
#  studebaker: -0.1394
#  ops: -0.1394
#  floyd: -0.1394
#  f0wqlobooy: -0.1394
#  358: -0.1394
#  iii: -0.1394
#  aussies: -0.1394
#  phones: -0.1394
#  bromleythe: -0.1394
#  double: -0.1394
#  yall: -0.1394
#  musbik7ejf: -0.1394
#  thpbdpdj35: -0.1394
#  johnson: -0.1394
#  tea: -0.1394
#  14: -0.1394
#  occasion: -0.1394
#  patrick: -0.1394
#  ad: -0.1394
#  clouds: -0.1394
#  therapies: -0.1394
#  mcilroy: -0.1394
#  cmon: -0.1394
#  democrats: -0.1394
#  cold: -0.1394
#  estate: -0.1394
#  be4: -0.1394
#  kasiakosek: -0.1394
#  desk: -0.1394
#  reed: -0.1394
#  mitt: -0.1394
#  sensanders: -0.1394
#  buzwjmw49e: -0.1394
#  8437150124: -0.1394
#  cpanel: -0.1394
#  ûïwe: -0.1394
#  3942: -0.1394
#  wrked: -0.1394
#  birkbje23e: -0.1394
#  christmas: -0.1394
#  glass: -0.1394
#  boyfriend: -0.1394
#  captain: -0.1394
#  leather: -0.1394
#  luv: -0.1394
#  4bcqzqjrzn: -0.1394
#  tru: -0.1394
#  wet: -0.1394
#  overtook: -0.1394
#  swords: -0.1394
#  policy: -0.1394
#  unique: -0.1394
#  starting: -0.1394
#  amalie: -0.1394
#  brain: -0.1394
#  respondents: -0.1394
#  y9wvqkgbbi: -0.1394
#  tape: -0.1394
#  s5f9fcomp8: -0.1394
#  s5: -0.1394
#  feet: -0.1394
#  oogoto76uz: -0.1394
#  ceo: -0.1394
#  starks: -0.1394
#  freestyle: -0.1394
#  greyjoys: -0.1394
#  ytnnnd631z: -0.1394
#  sustainable: -0.1394
#  fading: -0.1394
#  worse: -0.1394
#  consciousness: -0.1394
#  inning: -0.1394
#  compensate: -0.1394
#  captivity: -0.1394
#  selling: -0.1394
#  ohlordy: -0.1394
#  hw: -0.1394
#  introduced: -0.1394
#  legislation: -0.1394
#  ncjlxzfwaa: -0.1394
#  vhrlswvzql: -0.1394
#  take: -0.1394
#  addiction: -0.1394
#  discovered: -0.1394
#  autismawareness: -0.1394
#  bank: -0.1394
#  route: -0.1394
#  4cpnbbzkzg: -0.1394
#  orcas: -0.1394
#  parked: -0.1394
#  sikkg0fphr: -0.1394
#  eur: -0.1394
#  restricted: -0.1394
#  mine: -0.1394
#  jfyfzddlrn: -0.1394
#  spanish: -0.1394
#  crackdown: -0.1394
#  bwin: -0.1394
#  mystery: -0.1394
#  stocks: -0.1394
#  program: -0.1394
#  vs: -0.1394
#  truestory: -0.1394
#  modestmouseremix: -0.1394
#  powerful: -0.1394
#  traveling: -0.1394
#  qhfqlui6ry: -0.1394
#  ae9cpiexak: -0.1394
#  soap: -0.1394
#  heheh: -0.1394
#  stuffin: -0.1394
#  1200: -0.1394
#  strangers: -0.1394
#  elijahmallari: -0.1394
#  daniel: -0.1394
#  stray: -0.1394
#  jackass: -0.1394
#  twain: -0.1394
#  egcv7ybjae: -0.1394
#  jones94kyle: -0.1394
#  emotions: -0.1394
#  reshareworthy: -0.1394
#  tammy_w1997: -0.1394
#  trad: -0.1394
#  authors: -0.1394
#  2rtq9qmgpb: -0.1394
#  masses: -0.1394
#  plummeting: -0.1394
#  expecting: -0.1394
#  pajamas: -0.1394
#  cart: -0.1394
#  surprise: -0.1394
#  footed: -0.1394
#  maketh: -0.1394
#  sacrifice: -0.1394
#  3am: -0.1394
#  knocking: -0.1394
#  ankle: -0.1394
#  2oqsgzqlbz: -0.1394
#  724gq5ebqz: -0.1394
#  ercjmnea: -0.1394
#  h01j9pirie: -0.1394
#  aka: -0.1394
#  sedan: -0.1394
#  cry: -0.1394
#  osuoivnigo: -0.1394
#  rule: -0.1394
#  bake: -0.1394
#  legion: -0.1394
#  men: -0.1394
#  smiles: -0.1394
#  flew: -0.1394
#  senior: -0.1394
#  inevitable: -0.1394
#  microsoft: -0.1394
#  added: -0.1394
#  gravel: -0.1394
#  jack: -0.1394
#  thousands: -0.1394
#  mad: -0.1394
#  river: -0.1394
#  dnb: -0.1394
#  golf: -0.1394
#  album: -0.1394
#  ill: -0.1394
#  safely: -0.1394
#  reply: -0.1394
#  procedures: -0.1394
#  wife: -0.1394
#  sound: -0.1394
#  left: -0.1394
#  days: -0.1394
#  benefits: -0.1394
#  giving: -0.1394
#  gotta: -0.1394
#  player: -0.1394
#  summer: -0.1394
#  bayelsa: -0.1394
#  gt: -0.1394
#  need: -0.1394
#  whole: -0.0929
#  saving: -0.0929
#  time: -0.0929
#  there: -0.0929
#  my: -0.0929
#  place: -0.0929
#  followers: -0.0929
#  theres: -0.0929
#  ben: -0.0929
#  drum: -0.0929
#  much: -0.0929
#  become: -0.0929
#  dudairbbpo: -0.0929
#  padosfyxnm: -0.0929
#  blacklivesmatter: -0.0929
#  torch: -0.0929
#  lord: -0.0929
#  tootrue: -0.0929
#  mcwd37iof9: -0.0929
#  cree: -0.0929
#  bunch: -0.0929
#  casino: -0.0929
#  bets: -0.0929
#  boylesports: -0.0929
#  5ydb4s13pf: -0.0929
#  zildpvknxp: -0.0929
#  moral: -0.0929
#  allinwithchris: -0.0929
#  msnbc: -0.0929
#  apocalyptic: -0.0929
#  susanj357: -0.0929
#  willing: -0.0929
#  mum: -0.0929
#  radio: -0.0929
#  otherwise: -0.0929
#  _animaladvocate: -0.0929
#  kirstiealley: -0.0929
#  sbnation: -0.0929
#  xyi5fdacxo: -0.0929
#  am: -0.0929
#  sjtvzggcxu: -0.0929
#  old: -0.0929
#  improved: -0.0929
#  hurled: -0.0929
#  violators: -0.0929
#  nuked: -0.0929
#  la: -0.0929
#  opposite: -0.0929
#  drewwtaylor: -0.0929
#  granttamane8: -0.0929
#  visionzero: -0.0929
#  lobbied: -0.0929
#  dr_baseball41: -0.0929
#  lq4lxgs2xu: -0.0929
#  regular: -0.0929
#  fizzy: -0.0929
#  porcupine: -0.0929
#  seats: -0.0929
#  lie: -0.0929
#  dtop77: -0.0929
#  christie: -0.0929
#  hillside: -0.0929
#  iylvzy3cob: -0.0929
#  motordom: -0.0929
#  cavb7pgepv: -0.0929
#  snapchat: -0.0929
#  jewish: -0.0929
#  ejrme49rkd: -0.0929
#  8000: -0.0929
#  xoxo: -0.0929
#  different: -0.0929
#  rant: -0.0929
#  y8orqapwrk: -0.0929
#  9qnq45zduw: -0.0929
#  gm: -0.0929
#  hamptonroadsfor: -0.0929
#  dhyljllrhl: -0.0929
#  prayers: -0.0929
#  uvq41i3kx2: -0.0929
#  attention: -0.0929
#  follow: -0.0929
#  panic: -0.0929
#  sahq5uoahw: -0.0929
#  7k5shaiqiw: -0.0929
#  shower: -0.0929
#  equalizer: -0.0929
#  checks: -0.0929
#  danagould: -0.0929
#  waynesteratl: -0.0929
#  reporting: -0.0929
#  meant: -0.0929
#  blown: -0.0929
#  months: -0.0929
#  they: -0.0929
#  gays: -0.0929
#  separated: -0.0929
#  marynmck: -0.0929
#  noticed: -0.0929
#  adorable: -0.0929
#  crazy: -0.0929
#  cutlery: -0.0929
#  seek: -0.0929
#  robertwelch: -0.0929
#  gnzwxqktam: -0.0929
#  bq8kyi7gng: -0.0929
#  26: -0.0929
#  rules: -0.0929
#  screaming: -0.0929
#  audio: -0.0929
#  affected: -0.0929
#  one: -0.0929
#  soon: -0.0929
#  thursday: -0.0929
#  ish: -0.0929
#  colo: -0.0929
#  lzkely: -0.0929
#  administration: -0.0929
#  above: -0.0929
#  sweated: -0.0929
#  ames: -0.0929
#  jhaustin: -0.0929
#  illustration: -0.0929
#  healthcare: -0.0929
#  kodiak: -0.0929
#  indeed: -0.0929
#  ak: -0.0929
#  aqcsusqbdy: -0.0929
#  but: -0.0929
#  pluto: -0.0929
#  salmon: -0.0929
#  divided: -0.0929
#  adriennetomah: -0.0929
#  punished: -0.0929
#  pony: -0.0929
#  cbs3: -0.0929
#  ydgiuydqgb: -0.0929
#  big: -0.0929
#  punch: -0.0929
#  packs: -0.0929
#  shantae: -0.0929
#  text: -0.0929
#  structure: -0.0929
#  wztz4hgmvq: -0.0929
#  wiedemer: -0.0929
#  500: -0.0929
#  safe: -0.0929
#  photo: -0.0929
#  eqjcpwilvn: -0.0929
#  reject: -0.0929
#  alliance: -0.0929
#  initiative: -0.0929
#  assad: -0.0929
#  regime: -0.0929
#  tied: -0.0929
#  rocyyei2dm: -0.0929
#  64: -0.0929
#  average: -0.0929
#  friend59: -0.0929
#  lead: -0.0929
#  reach: -0.0929
#  swing: -0.0929
#  t94lnfwf34: -0.0929
#  accuses: -0.0929
#  macs: -0.0929
#  honeybunzgem: -0.0929
#  bug: -0.0929
#  primalkitchen: -0.0929
#  lab: -0.0929
#  os: -0.0929
#  sbgirvqvzb: -0.0929
#  plays: -0.0929
#  patched: -0.0929
#  paramedic: -0.0929
#  exploit: -0.0929
#  active: -0.0929
#  stages: -0.0929
#  along: -0.0929
#  feeling: -0.0929
#  espargaro: -0.0929
#  bread: -0.0929
#  vg7jnah0iw: -0.0929
#  flex: -0.0929
#  abandoning: -0.0929
#  2azxdlcxga: -0.0929
#  paints: -0.0929
#  tears: -0.0929
#  vancouver: -0.0929
#  kshsgwghfj: -0.0929
#  thank: -0.0929
#  usw: -0.0929
#  motogp: -0.0929
#  transport: -0.0929
#  layout: -0.0929
#  unrest: -0.0929
#  trial: -0.0929
#  1st: -0.0929
#  sm: -0.0929
#  marijuana: -0.0929
#  worries: -0.0929
#  rny4l3sr7a: -0.0929
#  funkflex: -0.0929
#  uncertainty: -0.0929
#  princessduck: -0.0929
#  indianapolis: -0.0929
#  igx8xfz8ko: -0.0929
#  dilawri: -0.0929
#  mrospd9878: -0.0929
#  code: -0.0929
#  appraisal: -0.0929
#  johns: -0.0929
#  moth: -0.0929
#  crowns: -0.0929
#  drug: -0.0929
#  subtle: -0.0929
#  smoothed: -0.0929
#  catch: -0.0929
#  chalked: -0.0929
#  bird: -0.0929
#  diss: -0.0929
#  nu6wrp716d: -0.0929
#  modernize: -0.0929
#  dhgavw8bsw: -0.0929
#  rhode: -0.0929
#  len: -0.0929
#  animallogic: -0.0929
#  ieansquad: -0.0929
#  dwilliams313: -0.0929
#  acarewornheart: -0.0929
#  mouse: -0.0929
#  pb: -0.0929
#  fella: -0.0929
#  pittsburgh: -0.0929
#  ap9jbrpmqg: -0.0929
#  gopdebate: -0.0929
#  0lmheaex9k: -0.0929
#  lotg: -0.0929
#  barcousky: -0.0929
#  joe: -0.0929
#  107: -0.0929
#  bundled: -0.0929
#  lynch: -0.0929
#  i6zqlk2puz: -0.0929
#  monroe: -0.0929
#  h31mmuduqt: -0.0929
#  dub: -0.0929
#  reacts: -0.0929
#  marilyn: -0.0929
#  salmanmydarling: -0.0929
#  bob: -0.0929
#  checking: -0.0929
#  todd: -0.0929
#  chachi: -0.0929
#  jackman: -0.0929
#  titortau: -0.0929
#  puppy: -0.0929
#  spinning: -0.0929
#  ripriprip: -0.0929
#  ripped: -0.0929
#  downgraded: -0.0929
#  ombudsmanship: -0.0929
#  loretta: -0.0929
#  larious: -0.0929
#  otblb9pj2i: -0.0929
#  jn8s0drwbp: -0.0929
#  arent: -0.0929
#  hhbu: -0.0929
#  rose: -0.0929
#  theory: -0.0929
#  damidnighter: -0.0929
#  dwarves: -0.0929
#  grille: -0.0929
#  jump: -0.0929
#  dorismatsui: -0.0929
#  installation: -0.0929
#  window: -0.0929
#  ims: -0.0929
#  544: -0.0929
#  irandeal: -0.0929
#  mounts: -0.0929
#  ho: -0.0929
#  youssefyamani: -0.0929
#  t6seku4yvm: -0.0929
#  amber: -0.0929
#  plastic: -0.0929
#  ace: -0.0929
#  playstation: -0.0929
#  zhsll7swbh: -0.0929
#  pretty: -0.0929
#  capoeira: -0.0929
#  supporting: -0.0929
#  tjoz4u4txl: -0.0929
#  speedtech: -0.0929
#  equation: -0.0929
#  pumper: -0.0929
#  mqfofkxtyh: -0.0929
#  faqnfupegn: -0.0929
#  cladding: -0.0929
#  alas: -0.0929
#  mfalcon21: -0.0929
#  trident: -0.0929
#  recipe: -0.0929
#  bedroom: -0.0929
#  stl: -0.0929
#  bearer: -0.0929
#  compliant: -0.0929
#  90225: -0.0929
#  paulista: -0.0929
#  audience: -0.0929
#  links: -0.0929
#  cleveland: -0.0929
#  shaker: -0.0929
#  cables: -0.0929
#  u0vdbrxfia: -0.0929
#  mencius: -0.0929
#  correct: -0.0929
#  retro: -0.0929
#  r1354: -0.0929
#  develop: -0.0929
#  925: -0.0929
#  9ckgggyvou: -0.0929
#  that_fat_guy: -0.0929
#  ring: -0.0929
#  aminespn: -0.0929
#  d12r8xpshy: -0.0929
#  opal: -0.0929
#  morganite: -0.0929
#  pawsox: -0.0929
#  stars: -0.0929
#  fox: -0.0929
#  ever: -0.0929
#  gemstone: -0.0929
#  durham: -0.0929
#  hhpvsatqxn: -0.0929
#  saw: -0.0929
#  discusses: -0.0929
#  woke: -0.0929
#  magner: -0.0929
#  name: -0.0929
#  tn: -0.0929
#  riwup1rbhu: -0.0929
#  listed: -0.0929
#  lionel: -0.0929
#  fashion: -0.0929
#  creel: -0.0929
#  mexican: -0.0929
#  feminists: -0.0929
#  slain: -0.0929
#  evildead: -0.0929
#  instructions: -0.0929
#  spfke5kqu4: -0.0929
#  psychologist: -0.0929
#  lgglf5yrme: -0.0929
#  usa: -0.0929
#  locomotives: -0.0929
#  grill: -0.0929
#  unknowingly: -0.0929
#  minecraft: -0.0929
#  mega: -0.0929
#  traction: -0.0929
#  breitbartnews: -0.0929
#  86pknkchmr: -0.0929
#  hazards: -0.0929
#  c2x0qokgly: -0.0929
#  wftv: -0.0929
#  1950: -0.0929
#  resistant: -0.0929
#  moron: -0.0929
#  magne: -0.0929
#  brainless: -0.0929
#  faced: -0.0929
#  faith: -0.0929
#  hashtags: -0.0929
#  xezbs3sq0y: -0.0929
#  exciting: -0.0929
#  55436: -0.0929
#  mullah: -0.0929
#  qxhowcv16r: -0.0929
#  dukes: -0.0929
#  hadn: -0.0929
#  suffer: -0.0929
#  religious: -0.0929
#  senschumer: -0.0929
#  qyu8grorq1: -0.0929
#  61: -0.0929
#  k4h8cq7puo: -0.0929
#  foolish: -0.0929
#  marksmaponyane: -0.0929
#  assume: -0.0929
#  ep: -0.0929
#  morning_joe: -0.0929
#  kinetic: -0.0929
#  tyewzf3hqa: -0.0929
#  tgxutuoyhl: -0.0929
#  knowledge: -0.0929
#  typography: -0.0929
#  cest: -0.0929
#  fpine: -0.0929
#  fri: -0.0929
#  wisdom: -0.0929
#  frickin: -0.0929
#  centers: -0.0929
#  emotion: -0.0929
#  celtic: -0.0929
#  dvonwiv3l1: -0.0929
#  newbie: -0.0929
#  lilithsaintcrow: -0.0929
#  teaching: -0.0929
#  noah: -0.0929
#  assholes: -0.0929
#  68: -0.0929
#  qmo1txxdkj: -0.0929
#  fl8gci84aj: -0.0929
#  selects: -0.0929
#  hey: -0.0929
#  hhs: -0.0929
#  delivered: -0.0929
#  sundowns: -0.0929
#  princeoffencing: -0.0929
#  presssec: -0.0929
#  fforecast: -0.0929
#  amsal: -0.0929
#  eswnsetftf: -0.0929
#  reince: -0.0929
#  improvement: -0.0929
#  brandonmulcahy: -0.0929
#  stavernise: -0.0929
#  worseits: -0.0929
#  gunned: -0.0929
#  mofo: -0.0929
#  decks: -0.0929
#  souls: -0.0929
#  shaznlmsfe: -0.0929
#  integrity: -0.0929
#  prohibits: -0.0929
#  ke1zs6naml: -0.0929
#  condos: -0.0929
#  unarmed: -0.0929
#  cs: -0.0929
#  asses: -0.0929
#  davidolszak: -0.0929
#  ruled: -0.0929
#  bias: -0.0929
#  dictator: -0.0929
#  munch: -0.0929
#  homukami: -0.0929
#  2ii3brc7nx: -0.0929
#  questioning: -0.0929
#  clapping: -0.0929
#  club: -0.0929
#  marvins: -0.0929
#  garbanzobean23: -0.0929
#  author: -0.0929
#  where: -0.0929
#  expression: -0.0929
#  hpa9gqrywa: -0.0929
#  regarding: -0.0929
#  agrees: -0.0929
#  bellerin: -0.0929
#  hoof: -0.0929
#  types: -0.0929
#  most: -0.0929
#  g7k9tqvqbk: -0.0929
#  species: -0.0929
#  gargoyle: -0.0929
#  cheeks: -0.0929
#  coil: -0.0929
#  fallontonight: -0.0929
#  rays: -0.0929
#  brokenscnecal: -0.0929
#  attempting: -0.0929
#  joint: -0.0929
#  hector: -0.0929
#  cutest: -0.0929
#  ecmj18azai: -0.0929
#  onshit: -0.0929
#  sweater: -0.0929
#  etuuyislhw: -0.0929
#  srs: -0.0929
#  seasonfrom: -0.0929
#  b5s5epj7um: -0.0929
#  9jxb3rx8mf: -0.0929
#  poured: -0.0929
#  y217ceeemd: -0.0929
#  subtlety: -0.0929
#  rs: -0.0929
#  blank: -0.0929
#  sundays: -0.0929
#  indot: -0.0929
#  stacedemon: -0.0929
#  youuu: -0.0929
#  mqmcolwbzc: -0.0929
#  brian: -0.0929
#  kamunt: -0.0929
#  mueller: -0.0929
#  gained: -0.0929
#  mommys: -0.0929
#  wtggqs5geh: -0.0929
#  phenomenal: -0.0929
#  spaniels: -0.0929
#  writer: -0.0929
#  pe2d3hcsni: -0.0929
#  byr: -0.0929
#  access: -0.0929
#  choice: -0.0929
#  monwabisi: -0.0929
#  nov: -0.0929
#  captures: -0.0929
#  newåêheights: -0.0929
#  ryt: -0.0929
#  b7zwevsrgo: -0.0929
#  _dangerousbeans: -0.0929
#  pirate: -0.0929
#  gamma: -0.0929
#  black: -0.0929
#  restaurant: -0.0929
#  believing: -0.0929
#  rjrmw7nzy5: -0.0929
#  roadid: -0.0929
#  aoesbvns45: -0.0929
#  emails: -0.0929
#  engle: -0.0929
#  holt: -0.0929
#  earners: -0.0929
#  ashestoashes: -0.0929
#  kristyleemusic: -0.0929
#  january: -0.0929
#  attic: -0.0929
#  mattcohen4fake: -0.0929
#  smokey: -0.0929
#  grazed: -0.0929
#  de: -0.0929
#  complaints: -0.0929
#  iglnqpgbnw: -0.0929
#  cocker: -0.0929
#  hikdc1fm2f: -0.0929
#  i7eskymoec: -0.0929
#  hlongwane: -0.0929
#  welshninja87: -0.0929
#  dancers: -0.0929
#  margarita: -0.0929
#  softenza: -0.0929
#  flawless: -0.0929
#  y33qckq7qd: -0.0929
#  0rsverlztm: -0.0929
#  lucymayofficial: -0.0929
#  boss: -0.0929
#  ebrointheam: -0.0929
#  roh3: -0.0929
#  throwback: -0.0929
#  faceless: -0.0929
#  rgtyzbnkeo: -0.0929
#  bennycapricon: -0.0929
#  wmoyibwec1: -0.0929
#  gidiexclusixe: -0.0929
#  spots: -0.0929
#  biggie: -0.0929
#  wineisdumb: -0.0929
#  2a: -0.0929
#  sonyprousa: -0.0929
#  equipments: -0.0929
#  drumming: -0.0929
#  oppose: -0.0929
#  thesewphist: -0.0929
#  cufi: -0.0929
#  9q9rk3fof7: -0.0929
#  objective: -0.0929
#  theboyofmasks: -0.0929
#  okay: -0.0929
#  burford: -0.0929
#  fuckface: -0.0929
#  bolstering: -0.0929
#  sputnikint: -0.0929
#  djiglobal: -0.0929
#  reusing: -0.0929
#  strickskin: -0.0929
#  doomsday: -0.0929
#  subway: -0.0929
#  evidence: -0.0929
#  2gljhvead9: -0.0929
#  fdbdp: -0.0929
#  blending: -0.0929
#  vpqtgeqlma: -0.0929
#  profbriancox: -0.0929
#  preppertalk: -0.0929
#  preppers: -0.0929
#  prepper: -0.0929
#  filming: -0.0929
#  jews: -0.0929
#  4arwwrzpsr: -0.0929
#  bakeofffriends: -0.0929
#  heels: -0.0929
#  sputnik: -0.0929
#  council: -0.0929
#  buddy: -0.0929
#  underwriter: -0.0929
#  emergencies: -0.0929
#  convert: -0.0929
#  8qqzyziaqf: -0.0929
#  musicians: -0.0929
#  cooperation: -0.0929
#  nickscomics: -0.0929
#  manor: -0.0929
#  mkjq9yfmp8: -0.0929
#  lumixusa: -0.0929
#  spam: -0.0929
#  chem: -0.0929
#  champaign: -0.0929
#  whoever: -0.0929
#  costs: -0.0929
#  shtf: -0.0929
#  listenlive: -0.0929
#  xn09mx6sxy: -0.0929
#  esn: -0.0929
#  cilla: -0.0929
#  wpt: -0.0929
#  identitytheft: -0.0929
#  chosen: -0.0929
#  backyard: -0.0929
#  motorcraft: -0.0929
#  promised: -0.0929
#  nukes: -0.0929
#  f7a66diiyk: -0.0929
#  budmke3nnf: -0.0929
#  subs: -0.0929
#  donations: -0.0929
#  rumah: -0.0929
#  smack: -0.0929
#  warrior: -0.0929
#  electronic: -0.0929
#  jake: -0.0929
#  summons: -0.0929
#  blasted: -0.0929
#  superintendent: -0.0929
#  matters: -0.0929
#  sxhw2tnnlf: -0.0929
#  sheeran: -0.0929
#  vplr5hka2u: -0.0929
#  combined: -0.0929
#  iowa: -0.0929
#  loving: -0.0929
#  pokemon: -0.0929
#  inmate: -0.0929
#  queens: -0.0929
#  temper: -0.0929
#  thuggin: -0.0929
#  homies: -0.0929
#  sneezing: -0.0929
#  lanjut: -0.0929
#  attempt: -0.0929
#  lanford: -0.0929
#  yagitudeh: -0.0929
#  oxrwrjzmnu: -0.0929
#  dirumah: -0.0929
#  slides: -0.0929
#  staining: -0.0929
#  gon: -0.0929
#  thehighfessions: -0.0929
#  cipinang: -0.0929
#  yilt1bb68k: -0.0929
#  beware: -0.0929
#  vector: -0.0929
#  coreyashe: -0.0929
#  swiming: -0.0929
#  stats: -0.0929
#  rifle: -0.0929
#  zoepzsoky1: -0.0929
#  illuminated: -0.0929
#  sonofliberty357: -0.0929
#  estellasrevenge: -0.0929
#  b8n6e4ryvz: -0.0929
#  firearm: -0.0929
#  brightly: -0.0929
#  sdogef3kft: -0.0929
#  cutter: -0.0929
#  smell: -0.0929
#  salvi: -0.0929
#  x0giy85bs8: -0.0929
#  bistro: -0.0929
#  basically: -0.0929
#  shorts: -0.0929
#  imagecomics: -0.0929
#  rejects: -0.0929
#  computer: -0.0929
#  hmuyzmv8qh: -0.0929
#  su: -0.0929
#  goku: -0.0929
#  idwpublishing: -0.0929
#  stony: -0.0929
#  beloeil: -0.0929
#  insides: -0.0929
#  directioners: -0.0929
#  marvel: -0.0929
#  transformed: -0.0929
#  expanding: -0.0929
#  richelieu: -0.0929
#  adoptive: -0.0929
#  felons: -0.0929
#  disasters: -0.0929
#  19: -0.0929
#  jeremyduns: -0.0929
#  dccomics: -0.0929
#  greetingcards: -0.0929
#  darkhorsecomics: -0.0929
#  assembly: -0.0929
#  dq: -0.0929
#  gap: -0.0929
#  kabk3tcjnl: -0.0929
#  dcubecrafts: -0.0929
#  temporary: -0.0929
#  customized: -0.0929
#  th: -0.0929
#  unconscious: -0.0929
#  enabling: -0.0929
#  slide: -0.0929
#  laurent: -0.0929
#  thousand: -0.0929
#  nafeezahmed: -0.0929
#  t07qxp5cbe: -0.0929
#  saint: -0.0929
#  pool: -0.0929
#  sirtophamhat: -0.0929
#  0wbecdmhqo: -0.0929
#  pnaqxprweg: -0.0929
#  scynic1: -0.0929
#  lulgzimbestpicts: -0.0929
#  positive: -0.0929
#  cheryl: -0.0929
#  finnish: -0.0929
#  charts: -0.0929
#  seem: -0.0929
#  dressing: -0.0929
#  tastes: -0.0929
#  soul: -0.0929
#  prepared: -0.0929
#  stephaniemarija: -0.0929
#  incessant: -0.0929
#  boring: -0.0929
#  web: -0.0929
#  ks57: -0.0929
#  kunstler: -0.0929
#  wq0jlshw1g: -0.0929
#  t6fuahfp7p: -0.0929
#  critical: -0.0929
#  beginning: -0.0929
#  decorating: -0.0929
#  nepd_loyko: -0.0929
#  nr8jjmpmos: -0.0929
#  exqkmlg4nj: -0.0929
#  nephew: -0.0929
#  decent: -0.0929
#  timeline: -0.0929
#  learned: -0.0929
#  cannabis: -0.0929
#  troyslaby22: -0.0929
#  oqjnuyibxm: -0.0929
#  tfl: -0.0929
#  earonlwifh: -0.0929
#  mud: -0.0929
#  iwk: -0.0929
#  hempoil: -0.0929
#  downtime: -0.0929
#  fit: -0.0929
#  ac6i3te8mt: -0.0929
#  privacy: -0.0929
#  pbohanna: -0.0929
#  workout: -0.0929
#  justaguess: -0.0929
#  jvai5vkmsy: -0.0929
#  jacket: -0.0929
#  umtnnimtbm: -0.0929
#  vcv73buacz: -0.0929
#  osteen: -0.0929
#  bzzdedcthl: -0.0929
#  difficulties: -0.0929
#  mlm: -0.0929
#  texans: -0.0929
#  doubt: -0.0929
#  icsfdsifqb: -0.0929
#  level: -0.0929
#  skipping: -0.0929
#  residualincome: -0.0929
#  sportinggoods: -0.0929
#  slamming: -0.0929
#  rhe7dxm7ey: -0.0929
#  dunking: -0.0929
#  dlvyfvnqee: -0.0929
#  _dangdaddy: -0.0929
#  qaqqrjv9gu: -0.0929
#  mining: -0.0929
#  roar: -0.0929
#  dreams: -0.0929
#  whose: -0.0929
#  yerct4j244: -0.0929
#  multidimensi: -0.0929
#  nhl: -0.0929
#  jw6fnnssxt: -0.0929
#  fairy: -0.0929
#  bearers: -0.0929
#  ymcglaun: -0.0929
#  advance: -0.0929
#  funniest: -0.0929
#  moonlight: -0.0929
#  icymi: -0.0929
#  hug: -0.0929
#  icrgseagya: -0.0929
#  4zaztb19qe: -0.0929
#  agqo1479xm: -0.0929
#  roblox: -0.0929
#  boxer: -0.0929
#  4head: -0.0929
#  dedicated: -0.0929
#  kpvymhm2ub: -0.0929
#  pale: -0.0929
#  dattomm: -0.0929
#  nowhere: -0.0929
#  v2yxurne2p: -0.0929
#  inbetween: -0.0929
#  wmv: -0.0929
#  bites: -0.0929
#  purified: -0.0929
#  weekend: -0.0929
#  8c3fploxcr: -0.0929
#  durant: -0.0929
#  definition: -0.0929
#  nba: -0.0929
#  insight: -0.0929
#  cacheadvance: -0.0929
#  songhey89: -0.0929
#  hospital: -0.0929
#  cbgz9xun2k: -0.0929
#  loveislove: -0.0929
#  jared: -0.0929
#  c8b6ddiqig: -0.0929
#  idm: -0.0929
#  hughes: -0.0929
#  preparing: -0.0929
#  behalf: -0.0929
#  worry: -0.0929
#  bnnidfzwbd: -0.0929
#  rationing: -0.0929
#  g0dn1chluo: -0.0929
#  reflected: -0.0929
#  sprains: -0.0929
#  mirrors: -0.0929
#  exclusive: -0.0929
#  classic: -0.0929
#  lexi_purduee: -0.0929
#  discuss: -0.0929
#  met: -0.0929
#  fiasco: -0.0929
#  laugh: -0.0929
#  strains: -0.0929
#  weeks: -0.0929
#  germany: -0.0929
#  bcs: -0.0929
#  relations: -0.0929
#  wouldn: -0.0929
#  gotham: -0.0929
#  stephen: -0.0929
#  interested: -0.0929
#  politely: -0.0929
#  runjewels: -0.0929
#  musician: -0.0929
#  6ce1vwovhs: -0.0929
#  bitches: -0.0929
#  newlyweds: -0.0929
#  grandpa: -0.0929
#  acmrm833zq: -0.0929
#  lowkey: -0.0929
#  davidcovucci: -0.0929
#  vh8qtbypzt: -0.0929
#  bayelsaåêstate: -0.0929
#  service: -0.0929
#  innocent: -0.0929
#  park: -0.0929
#  gum: -0.0929
#  nuggets: -0.0929
#  workforce: -0.0929
#  kaylak369: -0.0929
#  primary: -0.0929
#  goshen: -0.0929
#  ugh: -0.0929
#  inequality: -0.0929
#  jr: -0.0929
#  kp5dpoaf58: -0.0929
#  korea: -0.0929
#  namekians: -0.0929
#  grove: -0.0929
#  error: -0.0929
#  censor: -0.0929
#  magnetic: -0.0929
#  gorgeous: -0.0929
#  electrostatic: -0.0929
#  sks5jccrj2: -0.0929
#  hollyw: -0.0929
#  ctr: -0.0929
#  pgb2bmcfx8: -0.0929
#  opened: -0.0929
#  lnp: -0.0929
#  santiago: -0.0929
#  fusion: -0.0929
#  christianvalues: -0.0929
#  graveyard: -0.0929
#  court: -0.0929
#  beam: -0.0929
#  suny_orange: -0.0929
#  80dzgco6vc: -0.0929
#  bff: -0.0929
#  c22ecvl4hw: -0.0929
#  creation: -0.0929
#  pg4y3i5ciu: -0.0929
#  ai: -0.0929
#  em5opytbpg: -0.0929
#  conservation: -0.0929
#  blazing_ben: -0.0929
#  generational: -0.0929
#  stresses: -0.0929
#  joshuaassaraf: -0.0929
#  lay: -0.0929
#  revolt: -0.0929
#  broader: -0.0929
#  yllqjljiiq: -0.0929
#  diageo: -0.0929
#  gwfrazee: -0.0929
#  akgovbillwalker: -0.0929
#  foxy__siren: -0.0929
#  def: -0.0929
#  pattyds50: -0.0929
#  spirits: -0.0929
#  atlanta: -0.0929
#  stefano: -0.0929
#  speeding: -0.0929
#  however: -0.0929
#  nanotech: -0.0929
#  telegraphworld: -0.0929
#  gvm70u2bpm: -0.0929
#  invincible: -0.0929
#  woah: -0.0929
#  acfi2rhz4n: -0.0929
#  device: -0.0929
#  williams: -0.0929
#  constitutional: -0.0929
#  k4zomof319: -0.0929
#  km8ucihrrn: -0.0929
#  nottingham: -0.0929
#  scifi: -0.0929
#  detroit: -0.0929
#  billion: -0.0929
#  caraccidentlawyer: -0.0929
#  skinless: -0.0929
#  lenkaiswaifu: -0.0929
#  politic: -0.0929
#  mmmm: -0.0929
#  hfy5v3slbb: -0.0929
#  meme: -0.0929
#  clots: -0.0929
#  midnight: -0.0929
#  rear: -0.0929
#  i1vpkq9yag: -0.0929
#  upwards: -0.0929
#  predator: -0.0929
#  mistake: -0.0929
#  jumped: -0.0929
#  kinder: -0.0929
#  s2kxvm0cba: -0.0929
#  roger: -0.0929
#  stlouis: -0.0929
#  eaten: -0.0929
#  tbt: -0.0929
#  characters: -0.0929
#  zntg2wndmj: -0.0929
#  ty5gavn7uk: -0.0929
#  yumiko: -0.0929
#  fur: -0.0929
#  ya: -0.0929
#  gfa3sow9zn: -0.0929
#  options: -0.0929
#  yjth2nabv5: -0.0929
#  officially: -0.0929
#  squeeze: -0.0929
#  300m: -0.0929
#  dispatchers: -0.0929
#  combo: -0.0929
#  wadpp69lwj: -0.0929
#  supportive: -0.0929
#  campbell: -0.0929
#  lw2fglrgxb: -0.0929
#  boone: -0.0929
#  resemblance: -0.0929
#  economically: -0.0929
#  unions: -0.0929
#  5fhkxtrhyu: -0.0929
#  ks161: -0.0929
#  nashsnewvideo: -0.0929
#  epzwaseyky: -0.0929
#  nda: -0.0929
#  preview: -0.0929
#  esports: -0.0929
#  umtffa9jjb: -0.0929
#  wooooooo: -0.0929
#  kou: -0.0929
#  upa: -0.0929
#  9fxpixqujt: -0.0929
#  piss: -0.0929
#  progressive: -0.0929
#  phfoeozyps: -0.0929
#  rocks: -0.0929
#  crossfit: -0.0929
#  kind: -0.0929
#  salvages: -0.0929
#  moan: -0.0929
#  remade: -0.0929
#  tomatoes: -0.0929
#  7b2wf6ovfk: -0.0929
#  elm: -0.0929
#  diverse: -0.0929
#  staid: -0.0929
#  demeanor: -0.0929
#  clothes: -0.0929
#  gamerant: -0.0929
#  bills: -0.0929
#  publications: -0.0929
#  ireland: -0.0929
#  ykelquiban: -0.0929
#  76ehhmqq6r: -0.0929
#  needs: -0.0929
#  cfevtrsc1u: -0.0929
#  shirt: -0.0929
#  qamwojyahq: -0.0929
#  greetings: -0.0929
#  pens: -0.0929
#  hvwkjqxxyt: -0.0929
#  nurses: -0.0929
#  epsom: -0.0929
#  anutoopkf4: -0.0929
#  wimbledon: -0.0929
#  k1tmlwvjmj: -0.0929
#  eminem: -0.0929
#  nate: -0.0929
#  u6isxv2f3v: -0.0929
#  lefties: -0.0929
#  pediatric: -0.0929
#  lrt: -0.0929
#  dances: -0.0929
#  bm0qec7pja: -0.0929
#  doctors: -0.0929
#  yi30zgizsw: -0.0929
#  _rosewell: -0.0929
#  noises: -0.0929
#  michaelgbaron: -0.0929
#  2jgvhw7yzs: -0.0929
#  184: -0.0929
# ...
#  meat: 0.2323
#  kdwazhqtov: 0.2323
#  cm7hqwwulz: 0.2323
#  young: 0.2323
#  manufactured: 0.2323
#  encouragement: 0.2323
#  xw8sds1tjp: 0.2323
#  wosypvqufi: 0.2323
#  missing: 0.2323
#  power: 0.2323
#  given: 0.2323
#  settle: 0.2323
#  resort: 0.2323
#  light: 0.2323
#  destroy: 0.2323
#  question: 0.2323
#  further: 0.2323
#  go: 0.2323
#  philippines: 0.2323
#  canyon: 0.2323
#  vb3vfm76ke: 0.2323
#  breakingnews: 0.2323
#  recalls: 0.2323
#  fav: 0.2323
#  leader: 0.2323
#  ollymursaus: 0.2323
#  panicking: 0.2323
#  abc: 0.2323
#  terror: 0.2323
#  binellithresa: 0.2323
#  uan05tnksw: 0.2323
#  worried: 0.2323
#  hundreds: 0.2323
#  zourryart: 0.2323
#  passengers: 0.2323
#  thankful: 0.2323
#  alexalltimelow: 0.2323
#  cuties: 0.2323
#  gevrmbvznb: 0.2323
#  activated: 0.2323
#  purple: 0.2323
#  anthrax: 0.2323
#  cee: 0.2323
#  mkayla: 0.2323
#  wmata: 0.2323
#  childish: 0.2323
#  utter: 0.2323
#  petty: 0.2323
#  jeez: 0.2323
#  fart: 0.2323
#  cd: 0.2323
#  blakeshelton: 0.2323
#  jan: 0.2323
#  atomic: 0.2323
#  bay: 0.2323
#  xpddwh5tem: 0.2323
#  mumbai: 0.2323
#  bettyfreedoms: 0.2323
#  fyi: 0.2323
#  abninfvet: 0.2323
#  n2qzbmzuly: 0.2323
#  greer: 0.2323
#  unawares: 0.2323
#  _gaabyx: 0.2323
#  activist: 0.2323
#  trolley: 0.2323
#  disrupts: 0.2323
#  byvubg0wye: 0.2323
#  dumb: 0.2323
#  sandiego: 0.2323
#  building: 0.2323
#  granted: 0.2323
#  several: 0.2323
#  city: 0.2323
#  animal: 0.2323
#  threatens: 0.2323
#  volcanoes: 0.2323
#  remodeled: 0.2323
#  event: 0.2323
#  jab541hhk0: 0.2323
#  unsensibly: 0.2323
#  scott: 0.2323
#  je6zjwh5ub: 0.2323
#  fdxgmiwaeh: 0.2323
#  professionally: 0.2323
#  curb: 0.2323
#  outrun: 0.2323
#  jq2ib1ob1x: 0.2323
#  streak: 0.2323
#  avoid: 0.2323
#  field: 0.2323
#  bs: 0.2323
#  j4ggmkiney: 0.2323
#  refugees: 0.2323
#  spoiled: 0.2323
#  forbesasia: 0.2323
#  robertbenglund: 0.2323
#  severe: 0.2323
#  p1amginsys: 0.2323
#  couches: 0.2323
#  chubbysquirrel_: 0.2323
#  33333: 0.2323
#  hypo: 0.2323
#  closest: 0.2323
#  scenes: 0.2323
#  hurricane_surge: 0.2323
#  decor: 0.2323
#  aquarium: 0.2323
#  ornament: 0.2323
#  destroyer: 0.2323
#  sailing: 0.2323
#  theevilolives: 0.2323
#  horrific: 0.2323
#  hostage: 0.2323
#  email: 0.2323
#  www: 0.2323
#  hbdo22nqpz: 0.2323
#  melts: 0.2323
#  cataclysmic: 0.2323
#  wasn: 0.2323
#  reator: 0.2323
#  xzv0lt9zzk: 0.2323
#  mistaken: 0.2323
#  southern: 0.2323
#  ap: 0.2323
#  torrential: 0.2323
#  flooded: 0.2323
#  qszgjfuutu: 0.2323
#  r4kheh7iaf: 0.2323
#  lungs: 0.2323
#  warning: 0.2323
#  street: 0.2323
#  kc8o81bchg: 0.2323
#  lzml1xb2nh: 0.2323
#  digging: 0.2323
#  ember: 0.2323
#  chances: 0.2323
#  weathernetwork: 0.2323
#  vanilla: 0.2323
#  funeral: 0.2323
#  ja0wgp8spe: 0.2323
#  bulletproof: 0.2323
#  phase: 0.2323
#  georgia: 0.2323
#  talking: 0.2323
#  uqssnaattu: 0.2323
#  floatin: 0.2323
#  sejorg: 0.2323
#  fake: 0.2323
#  nljvp3vfyz: 0.2323
#  rescued: 0.2323
#  anarchy: 0.2323
#  czpdn9obit: 0.2323
#  usagov: 0.2323
#  tides: 0.2323
#  marks: 0.2323
#  climatechange: 0.2323
#  catches: 0.2323
#  fiya: 0.2323
#  following: 0.2323
#  blast: 0.2323
#  continually: 0.2323
#  em: 0.2323
#  accidentally: 0.2323
#  herself: 0.2323
#  case: 0.2323
#  trapped: 0.2323
#  godsfirstson1: 0.2323
#  coat: 0.2323
#  sidelines: 0.2323
#  practically: 0.2323
#  hella: 0.2323
#  abouts: 0.2323
#  glenstannard: 0.2323
#  grrrr: 0.2323
#  essexweather: 0.2323
#  past: 0.2323
#  response: 0.2323
#  cunayyh: 0.2323
#  taufikcj: 0.2323
#  enough: 0.2323
#  haydnexists: 0.2323
#  eye: 0.2323
#  nigeria: 0.2323
#  sad: 0.2323
#  xhnews: 0.2323
#  plants: 0.2323
#  yeah: 0.2323
#  ocean: 0.2323
#  whereas: 0.2323
#  superstitions: 0.2323
#  an3w16c8f6: 0.2323
#  dolphin: 0.2323
#  tweet4taiji: 0.2323
#  ron: 0.2323
#  pl2vzlrkvk: 0.2323
#  worship: 0.2323
#  reffbkvg9r: 0.2323
#  printing: 0.2323
#  ll: 0.2323
#  jez: 0.2323
#  genius: 0.2323
#  dave: 0.2323
#  im: 0.2323
#  arrested: 0.2323
#  edmonton: 0.2323
#  systems: 0.2323
#  dirk_nomissski: 0.2323
#  f8gvwkfqox: 0.2323
#  kendra_leigh13: 0.2323
#  faints: 0.2323
#  _chelsdelong12: 0.2323
#  migrants: 0.2323
#  windstorm: 0.2323
#  donate: 0.2323
#  indoors: 0.2323
#  tram: 0.2323
#  philly: 0.2323
#  slogan: 0.2323
#  rejected: 0.2323
#  stds: 0.2323
#  x17fubqbgg: 0.2323
#  acrylic: 0.2323
#  hrips_k: 0.2323
#  jittering: 0.2323
#  corpse: 0.2323
#  soft: 0.2323
#  jammu: 0.2323
#  rahulkanwal: 0.2323
#  applied: 0.2323
#  haunting: 0.2323
#  drawn: 0.2323
#  violentfeminazi: 0.2323
#  exposed: 0.2323
#  childsexabuse: 0.2323
#  armenians: 0.2323
#  nato: 0.2323
#  memphis: 0.2323
#  forecast: 0.2323
#  comparison: 0.2323
#  chibi877: 0.2323
#  shouted: 0.2323
#  dmassa5: 0.2323
#  cxyfqn3ue4: 0.2323
#  crown: 0.2323
#  definite: 0.2323
#  lyxnjlxl8s: 0.2323
#  free: 0.2323
#  versus: 0.2323
#  dig: 0.2323
#  hoke: 0.2323
#  excepting: 0.2323
#  dfljev: 0.2323
#  cross: 0.2323
#  modnao23: 0.2323
#  fucking: 0.2323
#  travel: 0.2323
#  zujwuiomb3: 0.2323
#  migraine: 0.2323
#  allows: 0.2323
#  er: 0.2323
#  automatic: 0.2323
#  support: 0.2323
#  blow: 0.2323
#  follows: 0.2323
#  hellfire: 0.2323
#  frog: 0.2323
#  quarantine: 0.2323
#  newep: 0.2323
#  theconspiracytheory: 0.2323
#  stacey: 0.2323
#  morning: 0.2323
#  murderous: 0.2323
#  victims: 0.2323
#  officials: 0.2323
#  abcnews: 0.2323
#  detonate: 0.2323
#  private: 0.2323
#  murfreesboro: 0.2323
#  parade: 0.2323
#  ww3: 0.2323
#  dice: 0.2323
#  kontrolled: 0.2323
#  run: 0.2323
#  demonization: 0.2323
#  thick: 0.2323
#  mariah: 0.2323
#  shoulders: 0.2323
#  meals: 0.2323
#  drunk: 0.2323
#  doctordryadma: 0.2323
#  bowl: 0.2323
#  bombed: 0.2323
#  zone: 0.2323
#  share: 0.2323
#  omfg: 0.2323
#  blood: 0.2323
#  him: 0.2323
#  peace: 0.2323
#  literally: 0.2788
#  weapons: 0.2788
#  exploration: 0.2788
#  pandemonium: 0.2788
#  responders: 0.2788
#  piece: 0.2788
#  murderer: 0.2788
#  mph: 0.2788
#  pm: 0.2788
#  economy: 0.2788
#  9naw3qoqol: 0.2788
#  searching: 0.2788
#  slowly: 0.2788
#  thunderstorm: 0.2788
#  drone: 0.2788
#  history: 0.2788
#  lost: 0.2788
#  considering: 0.2788
#  research: 0.2788
#  hwy: 0.2788
#  socialnews: 0.2788
#  05: 0.2788
#  swam: 0.2788
#  suffice: 0.2788
#  mess: 0.2788
#  bounced: 0.2788
#  global: 0.2788
#  dogs: 0.2788
#  md: 0.2788
#  municipal: 0.2788
#  trains: 0.2788
#  zsxqbduzbn: 0.2788
#  6ncfjxploy: 0.2788
#  01: 0.2788
#  khalidkkazi: 0.2788
#  un: 0.2788
#  7dyoglhmre: 0.2788
#  hkm3rtd4zf: 0.2788
#  deliver: 0.2788
#  suddenly: 0.2788
#  helicopter: 0.2788
#  ambulance: 0.2788
#  windstormåêinsurer: 0.2788
#  belter: 0.2788
#  92fwtobi3u: 0.2788
#  fireball: 0.2788
#  ashayo: 0.2788
#  coaches: 0.2788
#  lights: 0.2788
#  library: 0.2788
#  needed: 0.2788
#  colour: 0.2788
#  dress: 0.2788
#  learning: 0.2788
#  jets: 0.2788
#  legionnaires: 0.2788
#  snap: 0.2788
#  huge: 0.2788
#  honestly: 0.2788
#  at: 0.2788
#  structural: 0.2788
#  w0exzad5gc: 0.2788
#  issues: 0.2788
#  bridge: 0.2788
#  africa: 0.2788
#  nowplay: 0.2788
#  48h3tlvlxr: 0.2788
#  story: 0.2788
#  blah: 0.2788
#  exit: 0.2788
#  samples: 0.2788
#  ledofficial1: 0.2788
#  upset: 0.2788
#  sweets: 0.2788
#  requests: 0.2788
#  freak: 0.2788
#  must: 0.2788
#  mp: 0.2788
#  prebreak: 0.2788
#  c4news: 0.2788
#  v8aftd9zez: 0.2788
#  setting: 0.2788
#  ij: 0.2788
#  wrapped: 0.2788
#  h132iul7mu: 0.2788
#  displaced: 0.2788
#  refugee: 0.2788
#  point: 0.2788
#  sis: 0.2788
#  cyclist: 0.2788
#  citizens: 0.2788
#  thatsabinegirl: 0.2788
#  dose: 0.2788
#  elevated: 0.2788
#  friend50: 0.2788
#  hy5pbe12tm: 0.2788
#  humanity: 0.2788
#  wvobvvtxkg: 0.2788
#  famine: 0.2788
#  robdelaney: 0.2788
#  c1njpli5or: 0.2788
#  unable: 0.2788
#  engine: 0.2788
#  promise: 0.2788
#  ejaculating: 0.2788
#  bomber: 0.2788
#  ebola: 0.2788
#  rand: 0.2788
#  theyre: 0.2788
#  tnn: 0.2788
#  direction: 0.2788
#  medieval: 0.2788
#  9lo0hzwjpz: 0.2788
#  heyitsepark: 0.2788
#  counter: 0.2788
#  qzdqrbr4lh: 0.2788
#  alexandrian: 0.2788
#  helene: 0.2788
#  helene_yancey: 0.2788
#  reduce: 0.2788
#  own: 0.2788
#  gf: 0.2788
#  lamps: 0.2788
#  dude: 0.2788
#  new_hart2010: 0.2788
#  nuff: 0.2788
#  walls: 0.2788
#  colinhoffman29: 0.2788
#  breathing: 0.2788
#  political: 0.2788
#  caution: 0.2788
#  bjzssw4tid: 0.2788
#  saintsfc: 0.2788
#  currently: 0.2788
#  hyperbole: 0.2788
#  ghostwriter: 0.2788
#  currensy: 0.2788
#  9f3rdn9n3d: 0.2788
#  megaquake: 0.2788
#  doesn: 0.2788
#  m27329: 0.2788
#  1236: 0.2788
#  grounds: 0.2788
#  agents: 0.2788
#  plus: 0.2788
#  fedex: 0.2788
#  historic: 0.2788
#  blizzard: 0.2788
#  patient: 0.2788
#  crime: 0.2788
#  greenharvard: 0.2788
#  picture: 0.2788
#  triple: 0.2788
#  coffee: 0.2788
#  wraith: 0.2788
#  ldbao0rsuz: 0.2788
#  shadowflame: 0.2788
#  honda: 0.2788
#  psqd: 0.2788
#  unexercised: 0.2788
#  apollo: 0.2788
#  xfguklrltf: 0.2788
#  fegu8hwmc4: 0.2788
#  co: 0.2788
#  peacefully: 0.2788
#  west: 0.2788
#  montgomery: 0.2788
#  harper: 0.2788
#  taking: 0.2788
#  mwednesday: 0.2788
#  tinybaby: 0.2788
#  opposed: 0.2788
#  mattytalks: 0.2788
#  qwsbvflpe1: 0.2788
#  victory: 0.2788
#  adultblackmale: 0.2788
#  sleep: 0.2788
#  adamantly: 0.2788
#  crush: 0.2788
#  arsenal: 0.2788
#  committed: 0.2788
#  sign: 0.2788
#  scourgue: 0.2788
#  family: 0.2788
#  armageddon: 0.2788
#  ruining: 0.2788
#  sydney: 0.2788
#  protecting: 0.2788
#  back: 0.2788
#  electrocuted: 0.2788
#  stops: 0.2788
#  suspect: 0.2788
#  escape: 0.2788
#  driving: 0.2788
#  michigan: 0.2788
#  amid: 0.2788
#  down: 0.2788
#  american: 0.2788
#  spymiqnecj: 0.2788
#  mineness: 0.2788
#  related: 0.2788
#  bus: 0.2788
#  killing: 0.2788
#  101: 0.2788
#  may: 0.2788
#  was: 0.2788
#  oh: 0.2788
#  came: 0.2788
#  nah: 0.2788
#  obliterated: 0.2788
#  see: 0.2788
#  loud: 0.2788
#  california: 0.3253
#  were: 0.3253
#  attack: 0.3253
#  devastation: 0.3253
#  plane: 0.3253
#  buses: 0.3253
#  situation: 0.3253
#  heavy: 0.3253
#  update: 0.3253
#  satanaofhell: 0.3253
#  dreamy: 0.3253
#  taxis: 0.3253
#  pianohands: 0.3253
#  hard: 0.3253
#  deluged: 0.3253
#  coming: 0.3253
#  crisis: 0.3253
#  129: 0.3253
#  nine: 0.3253
#  texas: 0.3253
#  humofthecity: 0.3253
#  bilsko: 0.3253
#  gunman: 0.3253
#  redo: 0.3253
#  nails: 0.3253
#  afternoon: 0.3253
#  ayyy: 0.3253
#  libya: 0.3253
#  stealing: 0.3253
#  rescuers: 0.3253
#  clearly: 0.3253
#  angels: 0.3253
#  6whugaem3c: 0.3253
#  outside: 0.3253
#  aid: 0.3253
#  sick: 0.3253
#  ghostwriting: 0.3253
#  rihanna: 0.3253
#  ks94: 0.3253
#  myanmar: 0.3253
#  dm0uupqgwy: 0.3253
#  njlqrqcnl9: 0.3253
#  sophiewisey: 0.3253
#  wrecked: 0.3253
#  panda: 0.3253
#  control: 0.3253
#  simply: 0.3253
#  confirmed: 0.3253
#  boyinahorsemask: 0.3253
#  ready: 0.3253
#  jorrynja: 0.3253
#  cut: 0.3253
#  ter_ell: 0.3253
#  bf: 0.3253
#  leave: 0.3253
#  wild: 0.3253
#  hadnt: 0.3253
#  ryans: 0.3253
#  butgod: 0.3253
#  adip0unxhu: 0.3253
#  owner: 0.3253
#  thruuu: 0.3253
#  potential: 0.3253
#  blink: 0.3253
#  d4c2iqirnu: 0.3253
#  injured: 0.3253
#  wtf: 0.3253
#  3mtwh0jjns: 0.3253
#  looks: 0.3253
#  hearing: 0.3253
#  swallows: 0.3253
#  basic: 0.3253
#  grateful: 0.3253
#  ferguson: 0.3253
#  tomorrow: 0.3253
#  yyc: 0.3253
#  zaynmaiikist: 0.3253
#  beckyfeigin: 0.3253
#  crews: 0.3253
#  defs: 0.3253
#  in: 0.3253
#  server: 0.3253
#  apocalypse: 0.3253
#  overrun: 0.3253
#  alberta: 0.3253
#  involving: 0.3253
#  hollywarnexx: 0.3253
#  apaz: 0.3253
#  sport_en: 0.3253
#  izjk6kpwiz: 0.3253
#  rteugb5tnv: 0.3253
#  mothe: 0.3253
#  done: 0.3253
#  kemal_atlay: 0.3253
#  child: 0.3253
#  weather: 0.3253
#  plans: 0.3253
#  chick: 0.3253
#  mets: 0.3253
#  caught: 0.3253
#  oneheartonemindonecss: 0.3253
#  injury: 0.3253
#  heat: 0.3253
#  catastrophic: 0.3253
#  found: 0.3253
#  elephantintheroom: 0.3253
#  cyhitheprynce: 0.3253
#  causes: 0.3253
#  watching: 0.3253
#  true: 0.3253
#  mention: 0.3253
#  bagging: 0.3253
#  crushed: 0.3253
#  engulfed: 0.3253
#  shot: 0.3717
#  shit: 0.3717
#  whirlwind: 0.3717
#  towel: 0.3717
#  rexyy: 0.3717
#  temple: 0.3717
#  higher: 0.3717
#  watch: 0.3717
#  depressing: 0.3717
#  sir: 0.3717
#  g0r3zr1nqj: 0.3717
#  ain: 0.3717
#  royals: 0.3717
#  dalailama: 0.3717
#  lion: 0.3717
#  calgary: 0.3717
#  region: 0.3717
#  israel: 0.3717
#  wackos: 0.3717
#  udhampur: 0.3717
#  victim: 0.3717
#  sandstorm: 0.3717
#  dothraki: 0.3717
#  cos: 0.3717
#  lucysforsale: 0.3717
#  wveo9ed10e: 0.3717
#  here: 0.3717
#  israeli: 0.3717
#  eyesss: 0.3717
#  report: 0.3717
#  pyrbliss: 0.3717
#  wind: 0.3717
#  bound: 0.3717
#  clock: 0.3717
#  cases: 0.3717
#  coast: 0.3717
#  annihilated: 0.3717
#  8jxql8cv8z: 0.3717
#  3drsmxw3cr: 0.3717
#  neon: 0.3717
#  quarter: 0.3717
#  mnpdnashville: 0.3717
#  area: 0.3717
#  yo: 0.3717
#  pacific: 0.3717
#  syria: 0.3717
#  acid: 0.3717
#  omfgv9ma1w: 0.3717
#  swim: 0.3717
#  quarterstaff: 0.3717
#  aod2ftbmgu: 0.3717
#  talibans: 0.3717
#  kiranahmedd: 0.3717
#  annihilating: 0.3717
#  imagine: 0.3717
#  masturbates: 0.3717
#  5qhoehe9hf: 0.3717
#  obligations: 0.3717
#  bullets: 0.3717
#  hijacker: 0.3717
#  ol: 0.3717
#  meltdown: 0.3717
#  roll: 0.3717
#  20b3pnqxmd: 0.3717
#  sevenfigz: 0.3717
#  serious: 0.3717
#  truly: 0.3717
#  bomb: 0.3717
#  another: 0.3717
#  dm: 0.3717
#  which: 0.3717
#  alil: 0.3717
#  tha: 0.3717
#  dead: 0.3717
#  set: 0.3717
#  survivors: 0.4182
#  985dwwpdet: 0.4182
#  survive: 0.4182
#  s0eyq1wehe: 0.4182
#  btpqdehl3p: 0.4182
#  michael5sos: 0.4182
#  firefighters: 0.4182
#  incident: 0.4182
#  86rsyy2tng: 0.4182
#  twpl0nl8cx: 0.4182
#  casualty: 0.4182
#  bill_roose: 0.4182
#  disneyirh: 0.4182
#  countries: 0.4182
#  tatzfk63ch: 0.4182
#  police: 0.4182
#  science: 0.4182
#  mh370: 0.4182
#  nuclear: 0.4182
#  xrp0rtkffj: 0.4182
#  urufusanragu: 0.4182
#  thunder: 0.4182
#  0f8xa4ih1u: 0.4182
#  japan: 0.4182
#  outs: 0.4182
#  todd_calfee: 0.4182
#  mattburgener: 0.4182
#  those: 0.4182
#  jdtpirnm76: 0.4182
#  opens: 0.4182
#  cab: 0.4182
#  toddyrockstar: 0.4182
#  waited: 0.4182
#  sincere: 0.4182
#  smh: 0.4182
#  hoe: 0.4182
#  emmychappy: 0.4182
#  davidvonderhaar: 0.4182
#  weloveyoulouis: 0.4182
#  fllabzgcrc: 0.4182
#  wesleylowery: 0.4182
#  txetcysm1h: 0.4182
#  death: 0.4182
#  south: 0.4182
#  riveeeeeer: 0.4182
#  iiii: 0.4182
#  something: 0.4182
#  cdc: 0.4182
#  gainesville: 0.4182
#  drowned: 0.4182
#  russia: 0.4182
#  bigrigradio: 0.4182
#  awareness: 0.4182
#  thirsty: 0.4182
#  murder: 0.4182
#  allahsfinest12: 0.4182
#  tyyfg4qqvm: 0.4182
#  east: 0.4182
#  mount_wario: 0.4182
#  kirafrog: 0.4182
#  damn: 0.4182
#  mo: 0.4182
#  cloudy_goldrush: 0.4182
#  _301dc: 0.4182
#  sounds: 0.4182
#  hijacking: 0.4182
#  predict: 0.4182
#  flames: 0.4182
#  bleeding: 0.4182
#  did: 0.4182
#  rainstorm: 0.4647
#  didn: 0.4647
#  meeting: 0.4647
#  hostages: 0.4647
#  ltmgdp6jaf: 0.4647
#  happen: 0.4647
#  terrorist: 0.4647
#  pvmr38lnva: 0.4647
#  debris: 0.4647
#  train: 0.4647
#  balcony: 0.4647
#  car: 0.4647
#  __: 0.4647
#  c5u9qshhnb: 0.4647
#  collision: 0.4647
#  war: 0.4647
#  wave: 0.4647
#  evacuation: 0.4647
#  tank: 0.4647
#  accident: 0.4647
#  harms: 0.4647
#  village: 0.4647
#  riot: 0.4647
#  insomnia: 0.4647
#  tackettdc: 0.4647
#  fatalities: 0.4647
#  lordrsbiscuits: 0.4647
#  tiost8okvx: 0.4647
#  alextucker: 0.4647
#  hoo: 0.4647
#  woo: 0.4647
#  suing: 0.4647
#  hazardous: 0.4647
#  vygh2ni4ah: 0.4647
#  ouylwuixcs: 0.4647
#  horrible: 0.5112
#  call: 0.5112
#  teq7sri57p: 0.5112
#  bucs: 0.5112
#  witter: 0.5112
#  derailed: 0.5112
#  shooting: 0.5112
#  drought: 0.5112
#  balls: 0.5112
#  suicide: 0.5112
#  nothing: 0.5112
#  outbreak: 0.5112
#  risks: 0.5112
#  tragedy: 0.5112
#  imaginable: 0.5112
#  ipod: 0.5112
#  spill: 0.5112
#  umgd92wlja: 0.5112
#  snow: 0.5112
#  fatality: 0.5112
#  daviesmutia: 0.5112
#  aware: 0.5112
#  onto: 0.5112
#  gf5qjgoyci: 0.5112
#  distance: 0.5112
#  ehgtzhkan4: 0.5112
#  annihilation: 0.5112
#  m19ivwrdkk: 0.5112
#  butt: 0.5112
#  muslims: 0.5112
#  devastated: 0.5112
#  gas: 0.5112
#  landslide: 0.5112
#  piprhys: 0.5112
#  expect: 0.5112
#  snowstorm: 0.5112
#  poor: 0.5112
#  pileq: 0.5576
#  bioterrorism: 0.5576
#  bluebirddenver: 0.5576
#  qkrltrd39b: 0.5576
#  flood: 0.5576
#  derailment: 0.5576
#  apt: 0.5576
#  willienelson: 0.5576
#  xv3d9bpjhi: 0.5576
#  fandom: 0.5576
#  smithsonian: 0.5576
#  riots: 0.5576
#  mass: 0.5576
#  mall: 0.5576
#  nearly: 0.5576
#  truly_stings: 0.5576
#  deaths: 0.5576
#  qj3pvgavn7: 0.5576
#  weapon: 0.5576
#  near: 0.5576
#  boxing: 0.5576
#  shadow: 0.5576
#  hailstorm: 0.5576
#  begins: 0.6041
#  stab: 0.6041
#  volcano: 0.6041
#  jrowah: 0.6041
#  to9viqoofv: 0.6041
#  fire: 0.6041
#  chim: 0.6041
#  bit: 0.6041
#  iap4lwvqsw: 0.6041
#  flooding: 0.6041
#  tianta_: 0.6041
#  rioting: 0.6041
#  scene: 0.6041
#  comuiok3mp: 0.6041
#  yankees: 0.6041
#  mfs: 0.6041
#  forest: 0.6041
#  hand: 0.6041
#  sw1sbua3mn: 0.6506
#  collapse: 0.6506
#  crash: 0.6506
#  pikin: 0.6506
#  disaster: 0.6506
#  demons: 0.6506
#  bombing: 0.6506
#  zpxe3fmyng: 0.6506
#  x1392: 0.6506
#  tornado: 0.6506
#  hurricane_dolce: 0.6506
#  prob: 0.6506
#  hail: 0.6506
#  moly: 0.6506
#  ngkrzpza45: 0.6970
#  evacuated: 0.6970
#  allen_enbot: 0.6970
#  terrorism: 0.6970
#  explosion: 0.6970
#  evacuate: 0.6970
#  cyclone: 0.6970
#  fires: 0.7435
#  temecafreeman: 0.7435
#  ucsudk3q1d: 0.7435
#  burning: 0.7435
#  itss_selenaluna: 0.7435
#  extraordinaire: 0.7435
#  wildfire: 0.7435
#  casualties: 0.7435
#  collapsed: 0.7435
#  typhoon: 0.7900
#  hiroshima: 0.7900
#  hurricane_dame: 0.7900
#  damage: 0.7900
#  mudslide: 0.8364
#  floods: 0.8829
#  captainn_morgan: 0.8829
#  storm: 0.8829
#  sunburned: 0.9294
#  hurricane: 0.9294
#  massacre: 1.0688
#  earthquake: 1.2547

# %% [markdown]
# #### Deliverable 2.1
#
# Based on the training accuracy, do you conclude that the data are (mostly) linearly separable? Why or why not?
#
# [your answer here]
#
# #### Deliverable 2.2
#
# Which feature most increases the likelihood that the tweet does not refer to a real disaster, and which feature most increases the likelihood that the tweet refers to a real disaster?
#
# [your answer here]

# %% [markdown]
# #### Deliverable 2.3
# One technique for improving the resulting model with perceptron (or stochastic gradient descent learning in general) is to take an average of the weight vectors learned at different iterations of the algorithm, rather than only using the final weights that minimize the loss. That is, calculate $\bar{\mathbf{w}} = \sum_{t=1}^T \mathbf{w}^{(t)}$ where $\mathbf{w}^{(t)}$ is the weight vector at iteration $t$ of the algorithm and $T$ is the number of iterations, and then use $\bar{\mathbf{w}}$ when making classifications on new data.
#
# To use this technique in your classifier, add the keyword argument `average=True` to the `SGDClassifier` function. Try it now using the cells below.
#
# Compare the initial training/test accuracies to the training/test accuracies after doing averaging. What happens? Why do you think averaging the weights from different iterations has this effect?

# %% [markdown]
# [your answer here]

# %% [markdown]
# ## Problem 3: Logistic regression [4 points]
#
# For this problem, create a new `SGDClassifier`, this time setting the `loss` argument to `'log'`, which will train a logistic regression classifier. Set `average=False` for the remaining problems.
#
# Once you have trained the classifier, you can use the `predict` function to get the classifications, as with perceptron. Additionally, logistic regression provides probabilities for the predictions. You can get the probabilities by calling the `predict_proba` function. This will give a list of two numbers; the first is the probability that the class is $0$ and the second is the probability that the class is $1$.
#
#
# For the first task, add the keyword argument `alpha` to the `SGDClassifier` function. This is the regularization strength, called $\lambda$ in lecture. If you don't specify `alpha`, it defaults to $0.0001$. Experiment with other values and see how this affects the outcome.
#
# #### Deliverable 3.1:
#
# Calculate the training and testing accuracy when `alpha` is one of $[0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0]$. Create a plot where the x-axis is `alpha` and the y-axis is accuracy, with two lines (one for training and one for testing). You can borrow the code from HW1 for generating plots in Python. Use [a log scale for the x-axis](https://matplotlib.org/examples/pylab_examples/log_demo.html) so that the `alpha` values are spaced evenly.
#
# [your solution should be plotted below]

# %%
for alpha in [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0]:
    classifier = SGDClassifier(loss='log', max_iter=1000, alpha=alpha, tol=1.0e-12, random_state=123, eta0=100, average=False)
    classifier.fit(X_train, Y_train)
    print("Training accuracy: %0.6f" % accuracy_score(Y_train, classifier.predict(X_train)))
    print("Testing accuracy: %0.6f" % accuracy_score(Y_test, classifier.predict(X_test)))
# Out:
# Training accuracy: 0.983333
# Testing accuracy: 0.983333
# Training accuracy: 0.901634
# Testing accuracy: 0.901634
# Training accuracy: 0.808660
# Testing accuracy: 0.808660
# Training accuracy: 0.710784
# Testing accuracy: 0.710784
# Training accuracy: 0.674183
# Testing accuracy: 0.674183
# Training accuracy: 0.657026
# Testing accuracy: 0.657026
# Training accuracy: 0.567484
# Testing accuracy: 0.567484

# %% [markdown]
# #### Deliverable 3.2
#
# Examine the classifier probabilities using the `predict_proba` function when training with different values of `alpha`. What do you observe? How does `alpha` affect the prediction probabilities, and why do you think this happens?
#
# [your answer here]
#
# #### Deliverable 3.2.1
#
# Now remove the `alpha` argument so that it goes back to the default value. We'll now look at the effect of the learning rate. By default, `sklearn` uses an "optimal" learning rate based on some heuristics that work well for many problems. However, it can be good to see how the learning rate can affect the algorithm.
#
# For this task, add the keyword argument `learning_rate` to the `SGDClassifier` function and set the value to `invscaling`. This defines the learning rate at iteration $t$ as: $\eta_t = \frac{\eta_0}{t^a}$, where $\eta_0$ and $a$ are both arguments you have to define in the `SGDClassifier` function, called `eta0` and `power_t`, respectively. Experiment with different values of `eta0` and `power_t` and see how they affect the number of iterations it takes the algorithm to converge. You will often find that it will not finish within the maximum of $1000$ iterations.

# %% [markdown]
# #### Deliverable 3.3:
#
# Fill in the table below with the number of iterations for values of `eta0` in $[10.0, 100.0, 1000.0, 10000.0]$ and values of `power_t` in $[0.5, 1.0, 2.0]$. You may find it easier to write python code that can output the markdown for the table, but if you do that place the output here. If it does not converge within the maximum number of iterations (set to $1000$ by `max_iter`), record $1000$ as the number of iterations. You will need to read the documentation for this class to learn how to recover the actual number of iterations before reaching the stopping criterion.
#
# | `eta0`   | `power_t` | # Iterations |
# |-----------:|-----------|--------------|
# | $10.0$    | $0.5$     |              |
# | $10.0$    | $1.0$     |              |
# | $10.0$    | $2.0$     |              |
# | $100.0$   | $0.5$     |              |
# | $100.0$   | $1.0$     |              |
# | $100.0$   | $2.0$     |              |
# | $1000.0$  | $0.5$     |              |
# | $1000.0$  | $1.0$     |              |
# | $1000.0$  | $2.0$     |              |
# | $10000.0$ | $0.5$     |              |
# | $10000.0$ | $1.0$     |              |
# | $10000.0$ | $2.0$     |              |

# %% [markdown]
# #### Deliverable 3.4
#
# Describe how `eta0` and `power_t` affect the learning rate based on the formula (e.g., if you increase `power_t`, what will this do to the learning rate?), and connect this to what you observe in the table above.
#
# [your answer here]
#
# #### Deliverable 3.4.1
#
# Now remove the `learning_rate`, `eta0`, and `power_t` arguments so that the learning rate returns to the default setting. For this final task, we will experiment with how high the probabiity must be before an instance is classified as positive.
#
# The code below includes a function called `threshold` which takes as input the classification probabilities of the data (called `probs`, which is given by the function `predict_proba`) and a threshold (called `tau`, a scalar that should be a value between $0$ and $1$). It will classify each instance as $1$ if the probability of being $1$ is greater than `tau`, otherwise it will classify the instance as $0$. Note that if you set `tau` to $0.5$, the `threshold` function should give you exactly the same output as the classifier `predict` function.
#
# You should find that increasing the threshold causes the accuracy to drop. This makes sense, because you are classifying some things as 0 even though it's more probable that they are 1. So why do this? Suppose you care more about accurately identifying tweets about natural disasters than missing tweets about disasters (e.g. maybe you forward these tweets to first responders.) You thus want to be confident that when you classify a tweet as 1 that it really is 1.
#
# There is a metric called _precision_ which measures something like accuracy but for one specific class. Whereas accuracy is the percentage of tweets that were correctly classified, the precision of 1 would be the percentage of tweets classified as 1 that were correctly classified. (In other words, the number of tweets classified as 1 whose correct label was 1, divided by the number of tweets classified as 1.)
#
# You can use the [`precision_score`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score) function from `sklearn` to calculate the precision. It works much like the `accuracy_score` function.

# %%
# your answer here

# %% [markdown]
# #### Deliverable 3.5
#
# Calculate the testing precision when the value of `tau` for thresholding is one of $[0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99]$. Create a plot where the x-axis is `tau` and the y-axis is precision.
#
# [your solution should be plotted below]

# %%
# use this function for deliverable 3.5
def threshold(probs, tau):
    return np.where(probs[:,1] > tau, 1, 0)

# your logistic regression code here

classifier = SGDClassifier(loss='log', max_iter=1000, tol=1.0e-12, random_state=123)
classifier.fit(X_train, Y_train)
# Out:
# SGDClassifier(loss='log', random_state=123, tol=1e-12)

# %% [markdown]
# #### Deliverable 3.6
#
# Describe what you observe with thresholding (e.g., what happens to precision as the threshold increases?), and explain why you think this happens.

# %% [markdown]
# [your answer here]

# %% [markdown]
# ## Problem 4: Sparse learning [5604: 5 points; 4604: +3 EC points]
#
# Add the `penalty` argument to `SGDClassifier` and set the value to `'l1'`, which tells the algorithm to use L1 regularization instead of the default L2. Recall from lecture that L1 regularization encourages weights to stay at exactly $0$, resulting in a more "sparse" model than L2. You should see this effect if you examine the values of `classifier.coef_`.
#
# #### Deliverable 4.1: Write a function to calculate the number of features whose weights are nonzero when using L1 regularization. Calculate the number of nonzero feature weights when `alpha` is one of $[0.00001, 0.0001, 0.001, 0.01, 0.1]$. Create a plot where the x-axis is `alpha` and the y-axis is the number of nonzero weights, using a log scale for the x-axis.
#
# [your solution should be plotted below]

# %%
# your code here
