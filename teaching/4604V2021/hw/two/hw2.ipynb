# %% [markdown]
# # INFO-4604/5604 HW2: Linear Classification
#
# ### Solution by: *YOUR NAME* (and list any partners)

# %% [markdown]
# ## Assignment overview
#
# News agencies, governments and corporations sometimes track social media during natural disasters to try to monitor unfolding events. Because no single person or group of people can read all available Twitter data, organizations may turn to natural language processing methods to try and understand what is happening as disasters unfold.
#
# While this approach is powerful, inferring events from NLP can be tricky. For instance, say a person [tweets](https://twitter.com/AnyOtherAnnaK/status/629195955506708480) that "LOOK AT THE SKY LAST NIGHT IT WAS ABLAZE." This tweet includes the word "ablaze", which may signal to a computer that there is an unfolding disaster. However, in this particular case, the person is speaking metaphorically. A simple computer system using keywords (e.g. ablaze) might be fooled into thinking the tweet is reporting an actual fire.
#
# In principle, machine learning methods can balance multiple sources of evidence, which might do a better job and inferring which text refers to actual disasters. Therefore, in this assignment, you will thus predict if a given tweet actually refers to a natural disaster. This dataset originally comes from [Kaggle](https://www.kaggle.com/c/nlp-getting-started/overview).
#
#
# ### What to hand in
#
# You will submit the assignment on Canvas. Submit a single Jupyter notebook named `hw2lastname.ipynb`, where lastname is replaced with your last name. **Please also submit a PDF or HTML version of your notebook to Canvas**.
#
# Please clearly mark all deliverables. You are encouraged to create additional cells in whatever way makes the presentation more organized and easy to follow. You are allowed to import additional Python libraries.
#
# ### Submission policies
#
# - **Collaboration:** You are allowed to work with one partner. You are still expected to write up your own solution. Each individual must turn in their own submission, and list your collaborators after your name.
# - **Late submissions:** Each student may use up to 5 late days over the semester. You have late days, not late hours. This means that if your submission is late by any amount of time past the deadline, then this will use up a late day. If it is late by any amount beyond 24 hours past the deadline, then this will use a second late, and so on. Once you have used up all late days, late assignments will be given at most 80% credit after one day and 60% credit after two days.

# %% [markdown]
# ## Getting started
#
# In this assignment, you will experiment with perceptron and logistic regression in `sklearn`. Much of the code has already been written for you. We will use a class called `SGDClassifier` (which you should read about in the [sklearn documentation](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html)), which  implements stochastic gradient descent (SGD) for a variety of loss functions, including both perceptron and logistic regression, so this will be a way to easily move between the two classifiers.
#
# The code below will load the datasets. There are two data collections: the "training" data, which contains the tweets that you will use for training the classifiers, and the "testing" data, which are tweets that you will use to measure the classifier accuracy. The test tweets are instances the classifier has never seen before, so they are a good way to see how the classifier will behave on data it hasn't seen before. However, we still know the labels of the test tweets, so we can measure the accuracy.
#
# For this problem, we will use what are called "bag of words" features, which are commonly used when doing classification with text. Each feature is a word, and the value of a feature for a particular tweet is number of times the word appears in the tweet (with value $0$ if the word does not appear in the tweet).
#
# A note on labels: **If `Y_train` or `Y_test` are 1 this means the tweet refers to a real disaster; if the values are 0, it means the tweet does not refer to a real disaster**
#
# Run the block of code below to load the data. You don't need to do anything yet. Move on to "Problem 1" next.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

df_train = pd.read_csv('train.csv')

Y_train = df_train["target"]
text_train = df_train["text"]

vec = CountVectorizer()
X_train = vec.fit_transform(text_train)
feature_names = np.asarray(vec.get_feature_names())

df_test = pd.read_csv('test.csv')
Y_test = df_train["target"]
text_test = df_train["text"]

X_test = vec.transform(text_test)

# %% [markdown]
# ## Problem 1: Understand the data [6 points]
#
# Before doing anything else, take time to understand the code above.
#
# The variables `df_train` and `df_test` are dataframes that store the training (and testing) datasets, which are contained in tab-separated files where the first column is the label and the second column is the text of the tweet.
#
# The [`CountVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) class converts the raw text into a bag-of-words into a feature vector representation that `sklearn` can use.
#
# You should print out the values of the variables and write any other code needed to answer the following questions.
#
# #### Deliverable 1.1
#
# How many training instances are in the dataset? How many test instances?
#
# [your answer here]
#
# #### Deliverable 1.2
#
# How many features are in the training data?
#
# [your answer here]
#
# #### Deliverable 1.3
#
# What is the distribution of labels in the training data? That is, what percentage of instances are about actual disasters?
#
# [your answer here]

# %% [markdown]
# ## Problem 2: Perceptron [6 points]
#
# The code below trains an [`SGDClassifier`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html) using the perceptron loss, then it measures the accuracy of the classifier on the test data, using `sklearn`'s [`accuracy_score`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html) function.
#
# The `fit` function trains the classifier. The feature weights are stored in the `coef_` variable after training. The `predict` function of the trained `SGDClassifier` outputs the predicted label for a given instance or list of instances.
#
# Additionally, this code displays the features and their weights in sorted order, which you may want to examine to understand what the classifier is learning. In general, in binary classification, the 0 class is considered the "negative" class.
#
# There are 3 keyword arguments that have been added to the code below. It is important you keep the same values of these arguments whenever you create an `SGDClassifier` instance in this assignment so that you get consistent results. They are:
#
# - `max_iter` is one of the stopping criteria, which is the maximum number of iterations/epochs the algorithm will run for.
#
# - `tol` is the other stopping criterion, which is how small the difference between the current loss and previous loss should be before stopping.
#
# - `random_state` is a seed for pseudorandom number generation. The algorithm uses randomness in the way the training data are sorted, which will affect the solution that is learned, and even the accuracy of that solution.
#
# Note: *Wait a minute $-$ in class we learned that the loss function is convex, so the algorithm will find the same minimum regardless of how it is trained. Why is there random variation in the output? The reason is that even though there is only one minimum value of the loss, there may be different weights that result in the same loss, so randomness is a matter of tie-breaking. What's more, while different weights may have the same loss, they could lead to different classification accuracies, because the loss function is not the same as accuracy. (Unless accuracy was your loss function... which is possible, but uncommon because it turns out to be a difficult function to optimize.)
# Note that different computers may still give different answers, despite keeping these settings the same, because of how pseudorandom numbers are generated with different operating systems and Python environments.*
#
# To begin, run the code in the cell below without modification.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, precision_score

classifier = SGDClassifier(loss='perceptron', max_iter=1000, tol=1.0e-12, random_state=123, eta0=100)
classifier.fit(X_train, Y_train)

print("Number of SGD iterations: %d" % classifier.n_iter_)
print("Training accuracy: %0.6f" % accuracy_score(Y_train, classifier.predict(X_train)))
print("Testing accuracy: %0.6f" % accuracy_score(Y_test, classifier.predict(X_test)))

print("\nFeature weights:")
args = np.argsort(classifier.coef_[0])
for a in args:
    print(" %s: %0.4f" % (feature_names[a], classifier.coef_[0][a]))
# Out:
# Number of SGD iterations: 41
# Training accuracy: 0.985026
# Testing accuracy: 0.985026
#
# Feature weights:
#  zy3hpdjnwg: -0.5429
#  qzlpfhpwdo: -0.4790
#  song: -0.4152
#  desire: -0.4152
#  pile: -0.3832
#  permanently: -0.3832
#  qzqc8wwwcn: -0.3832
#  mode: -0.3513
#  significance: -0.3513
#  better: -0.3513
#  f7wqpcekg2: -0.3513
#  phone: -0.3513
#  poll: -0.3513
#  t5trhjuau0: -0.3513
#  myself: -0.3513
#  6gldwx71da: -0.3513
#  throw: -0.3513
#  eyes: -0.3513
#  nature: -0.3194
#  ebay: -0.3194
#  answer: -0.3194
#  scared: -0.3194
#  market: -0.3194
#  dianneg: -0.3194
#  selfies: -0.3194
#  m5djllxozp: -0.3194
#  hrqcjdovjz: -0.3194
#  hands: -0.3194
#  themselves: -0.3194
#  tickets: -0.3194
#  join: -0.3194
#  long: -0.2874
#  practice: -0.2874
#  6lojoorouk: -0.2874
#  vet: -0.2874
#  mickinyman: -0.2874
#  theatlantic: -0.2874
#  pissed: -0.2874
#  donnie: -0.2874
#  art: -0.2874
#  feels: -0.2874
#  open: -0.2874
#  quick: -0.2874
#  fact: -0.2874
#  statistically: -0.2874
#  dlaub2nvtn: -0.2874
#  wackoes: -0.2874
#  lethal: -0.2874
#  zdj2hyf6ro: -0.2874
#  complete: -0.2874
#  m8mvdspjp7: -0.2874
#  never: -0.2555
#  party: -0.2555
#  cameronhigdon34: -0.2555
#  best: -0.2555
#  tough: -0.2555
#  exited: -0.2555
#  future: -0.2555
#  presence: -0.2555
#  lets: -0.2555
#  show: -0.2555
#  put: -0.2555
#  6xsbddlziy: -0.2555
#  ed1vpitswy: -0.2555
#  pregnant: -0.2555
#  appears: -0.2555
#  also: -0.2555
#  mayonnaise: -0.2555
#  wished: -0.2555
#  spilt: -0.2555
#  0fekgyby5f: -0.2555
#  contact: -0.2555
#  talk: -0.2555
#  sww0qsmxvm: -0.2555
#  bcdp4gkoka: -0.2555
#  7npbfrzejl: -0.2555
#  y0kbyy8nce: -0.2555
#  patrick: -0.2555
#  hahahaha: -0.2555
#  wedding: -0.2555
#  3ejl9lzlch: -0.2555
#  lmao: -0.2555
#  2wvmij5sa4: -0.2555
#  cake: -0.2555
#  movies: -0.2555
#  5zdbtktww7: -0.2555
#  esemjrn5cc: -0.2555
#  sit: -0.2555
#  jeb: -0.2555
#  broke: -0.2555
#  pre: -0.2555
#  albums: -0.2555
#  kk8cnppzmk: -0.2555
#  tribal: -0.2555
#  games: -0.2555
#  seat: -0.2555
#  3yu26v19zh: -0.2555
#  ancient: -0.2235
#  use: -0.2235
#  lucky: -0.2235
#  joe: -0.2235
#  9mkzpzfkl2: -0.2235
#  8j4rdwyjwu: -0.2235
#  ocd: -0.2235
#  dying: -0.2235
#  sun: -0.2235
#  x2wn7o2a3w: -0.2235
#  cityofmemphis: -0.2235
#  common: -0.2235
#  saying: -0.2235
#  stronger: -0.2235
#  epicentre: -0.2235
#  friends: -0.2235
#  bridges: -0.2235
#  friend: -0.2235
#  messed: -0.2235
#  17egmlni80: -0.2235
#  stock: -0.2235
#  conversations: -0.2235
#  mido: -0.2235
#  present: -0.2235
#  bitch: -0.2235
#  missleylaha: -0.2235
#  felt: -0.2235
#  shedding: -0.2235
#  load: -0.2235
#  character: -0.2235
#  gopdebate: -0.2235
#  agony: -0.2235
#  09: -0.2235
#  pop: -0.2235
#  arizona: -0.2235
#  either: -0.2235
#  super: -0.2235
#  ur: -0.2235
#  2oroyunym2: -0.2235
#  c9jnxz3dxc: -0.2235
#  l9mb2j5pxg: -0.2235
#  saturday: -0.2235
#  booksbyroger: -0.2235
#  likely: -0.2235
#  doors: -0.2235
#  risk: -0.2235
#  such: -0.2235
#  bite: -0.2235
#  soaking: -0.2235
#  everything: -0.2235
#  wont: -0.2235
#  sure: -0.2235
#  bags: -0.2235
#  lot: -0.2235
#  naked: -0.2235
#  radneck: -0.2235
#  james: -0.2235
#  australia: -0.2235
#  jobs: -0.2235
#  9lyx7zmthe: -0.2235
#  5pbc96rtmj: -0.2235
#  gop: -0.2235
#  h6amecx5k7: -0.2235
#  b8iwrdxcm0: -0.2235
#  idc: -0.2235
#  madinah: -0.2235
#  x8moyevjsj: -0.2235
#  prophetmuhammad: -0.2235
#  jmzcaqydfa: -0.2235
#  yl67dkf4tb: -0.2235
#  nzrwddlntp: -0.2235
#  turns: -0.2235
#  writing: -0.2235
#  nice: -0.2235
#  daddy: -0.2235
#  becarefulharry: -0.2235
#  defendbutera: -0.2235
#  ruin: -0.2235
#  origin: -0.2235
#  angry: -0.2235
#  nowplaying: -0.2235
#  steps: -0.2235
#  august: -0.2235
#  deep: -0.2235
#  cook: -0.2235
#  away: -0.1916
#  whippenz: -0.1916
#  hall: -0.1916
#  b2yvlmpepr: -0.1916
#  beat: -0.1916
#  hero: -0.1916
#  used: -0.1916
#  gotten: -0.1916
#  men: -0.1916
#  arts: -0.1916
#  partially: -0.1916
#  blinker: -0.1916
#  srruqfffr6: -0.1916
#  cadzxagmsi: -0.1916
#  piling: -0.1916
#  yebxxarybf: -0.1916
#  lmumzkltln: -0.1916
#  ûªd: -0.1916
#  growing: -0.1916
#  zombie: -0.1916
#  gpcecp9khv: -0.1916
#  jose: -0.1916
#  pun: -0.1916
#  mercury: -0.1916
#  evil: -0.1916
#  occasion: -0.1916
#  guns: -0.1916
#  53: -0.1916
#  miss: -0.1916
#  rockbottomradfm: -0.1916
#  adorableappple: -0.1916
#  po: -0.1916
#  horse: -0.1916
#  mmda: -0.1916
#  tg5fqc8zey: -0.1916
#  8u07foqjzw: -0.1916
#  ox3qb15lwq: -0.1916
#  challenges: -0.1916
#  xqiadg9h2w: -0.1916
#  ypeelmjdzy: -0.1916
#  huffpostcomedy: -0.1916
#  attendees: -0.1916
#  blazing: -0.1916
#  j7hukhwmal: -0.1916
#  xwvw1sft4i: -0.1916
#  sitting: -0.1916
#  same: -0.1916
#  w3rga0nkom: -0.1916
#  0tzsqe8esd: -0.1916
#  mary: -0.1916
#  kindle: -0.1916
#  fzujg7sxjg: -0.1916
#  ball: -0.1916
#  aftershock: -0.1916
#  standwithpp: -0.1916
#  v5gtunwohy: -0.1916
#  babes: -0.1916
#  god: -0.1916
#  jhupogbvs8: -0.1916
#  gunning: -0.1916
#  surprise: -0.1916
#  romance: -0.1916
#  heartache: -0.1916
#  dinallyhot: -0.1916
#  aren: -0.1916
#  upon: -0.1916
#  alcohol: -0.1916
#  clinton: -0.1916
#  full: -0.1916
#  drive: -0.1916
#  giving: -0.1916
#  lmfao: -0.1916
#  write: -0.1916
#  impact: -0.1916
#  bears: -0.1916
#  decided: -0.1916
#  wrong: -0.1916
#  ym3cww28dj: -0.1916
#  trip: -0.1916
#  supernatural: -0.1916
#  trail: -0.1916
#  beginning: -0.1916
#  vest: -0.1916
#  dungeon: -0.1916
#  adam: -0.1916
#  foxnewsinsider: -0.1916
#  spend: -0.1916
#  weighs: -0.1916
#  eatfro3d5x: -0.1916
#  gg: -0.1916
#  summer2k15: -0.1916
#  scraped: -0.1916
#  grade: -0.1916
#  mindless: -0.1916
#  cufgvupkzi: -0.1916
#  looking: -0.1916
#  pardon: -0.1916
#  jones94kyle: -0.1916
#  cat: -0.1916
#  capacity: -0.1916
#  6ysbcsszys: -0.1916
#  diss: -0.1916
#  vault: -0.1916
#  justinbieber: -0.1916
#  todayng: -0.1916
#  straight: -0.1916
#  innovative: -0.1916
#  z3nevglufm: -0.1916
#  buy: -0.1916
#  devybnvxgq: -0.1916
#  pb2n77nskz: -0.1916
#  stone: -0.1916
#  rea: -0.1916
#  dope: -0.1916
#  parents: -0.1916
#  harrybecareful: -0.1916
#  clean: -0.1916
#  gujnpljvvt: -0.1916
#  nqiobczkrt: -0.1916
#  muscle: -0.1916
#  lady: -0.1916
#  rtfirzcpoc: -0.1916
#  cx6aupnemu: -0.1916
#  slightest: -0.1916
#  stirring: -0.1916
#  njrjxqbjr4: -0.1916
#  hasn: -0.1916
#  johndcgow: -0.1916
#  writebothfists: -0.1916
#  republicans: -0.1916
#  probably: -0.1916
#  online: -0.1916
#  louis: -0.1916
#  nasty: -0.1916
#  entire: -0.1916
#  matijwkzbh: -0.1916
#  holdin: -0.1916
#  celebrations: -0.1916
#  skyline: -0.1916
#  hang: -0.1916
#  dey: -0.1916
#  4i0kz2akly: -0.1916
#  dub: -0.1916
#  salmanmydarling: -0.1916
#  disney: -0.1916
#  2005: -0.1916
#  career: -0.1916
#  generation: -0.1916
#  jumped: -0.1916
#  unless: -0.1916
#  sale: -0.1916
#  mortal: -0.1916
#  kombat: -0.1916
#  diving: -0.1916
#  lhpgxc4b8j: -0.1916
#  row: -0.1916
#  khd99oz7u3: -0.1916
#  skirt: -0.1916
#  5cwuylnfum: -0.1916
#  1tyyqfz13d: -0.1916
#  river: -0.1916
#  chemical: -0.1916
#  cleared: -0.1597
#  their: -0.1597
#  books: -0.1597
#  movie: -0.1597
#  bed: -0.1597
#  terrible: -0.1597
#  middle: -0.1597
#  book: -0.1597
#  mine: -0.1597
#  woke: -0.1597
#  self: -0.1597
#  girlfriend: -0.1597
#  sunshine: -0.1597
#  blessed: -0.1597
#  2rtq9qmgpb: -0.1597
#  flag: -0.1597
#  masses: -0.1597
#  side: -0.1597
#  mcdonalds: -0.1597
#  ya: -0.1597
#  firework: -0.1597
#  runs: -0.1597
#  lr4btvueom: -0.1597
#  machines: -0.0958
#  ymuti3nd9r: -0.0958
#  aog5chjmvs: -0.0958
#  afc: -0.0958
#  stylishly: -0.0958
#  au3dbci7nf: -0.0958
#  covered: -0.0958
#  david_hurn: -0.0958
#  skynet: -0.0958
#  bovjrf62t7: -0.0958
#  73umw2igrz: -0.0958
#  unique: -0.0958
#  tokteacher: -0.0958
#  relevance: -0.0958
#  morehouse64: -0.0958
#  ethical: -0.0958
#  faroeislands: -0.0958
#  fqmyprlg9g: -0.0958
#  muppet: -0.0958
#  shad: -0.0958
#  forsythe: -0.0958
#  fkhanage: -0.0958
#  afterwards: -0.0958
#  savour: -0.0958
#  sigue: -0.0958
#  prolong: -0.0958
#  day: -0.0958
#  catholicism: -0.0958
#  homophobia: -0.0958
#  ep: -0.0958
#  ask: -0.0958
#  sneezing: -0.0958
#  questions: -0.0958
#  smack: -0.0958
#  hair: -0.0958
#  doctors: -0.0958
#  specialized: -0.0958
#  pediatric: -0.0958
#  k1tmlwvjmj: -0.0958
#  vampiro: -0.0958
#  loving: -0.0958
#  summon: -0.0958
#  directly: -0.0958
#  waved: -0.0958
#  latin: -0.0958
#  yhh7x0maio: -0.0958
#  sucks: -0.0958
#  misled: -0.0958
#  seem: -0.0958
#  stern: -0.0958
#  qbecjli7cx: -0.0958
#  aids: -0.0958
#  argentina: -0.0958
#  m2y9ym3if6: -0.0958
#  reasons: -0.0958
#  actively: -0.0958
#  ugc: -0.0958
#  6mbpvwitxf: -0.0958
#  emhub: -0.0958
#  embraced: -0.0958
#  audiences: -0.0958
#  rubber: -0.0958
#  streets: -0.0958
#  knocking: -0.0958
#  bring: -0.0958
#  x1441: -0.0958
#  vcv73buacz: -0.0958
#  tarmineta3: -0.0958
#  stamp: -0.0958
#  shower: -0.0958
#  namffldh5h: -0.0958
#  required: -0.0958
#  z8r6r3nbtb: -0.0958
#  60: -0.0958
#  property: -0.0958
#  favor: -0.0958
#  writer: -0.0958
#  sub: -0.0958
#  remainontop: -0.0958
#  freestyle: -0.0958
#  gregorysanders: -0.0958
#  oogoto76uz: -0.0958
#  stat: -0.0958
#  therealrittz: -0.0958
#  zqrcptlrum: -0.0958
#  lightrail: -0.0958
#  amalie: -0.0958
#  usdot: -0.0958
#  tuning: -0.0958
#  schedule: -0.0958
#  beloeil: -0.0958
#  mcilroy: -0.0958
#  defense: -0.0958
#  rationing: -0.0958
#  size: -0.0958
#  hmuyzmv8qh: -0.0958
#  saint: -0.0958
#  lbmekyphm5: -0.0958
#  expanding: -0.0958
#  freezing: -0.0958
#  member: -0.0958
#  oia5fxi4gm: -0.0958
#  diet: -0.0958
#  laurent: -0.0958
#  richelieu: -0.0958
#  manly: -0.0958
#  starting: -0.0958
#  nuggets: -0.0958
#  indeed: -0.0958
#  laughing: -0.0958
#  audio: -0.0958
#  max: -0.0958
#  t1mbw0ia3o: -0.0958
#  bills: -0.0958
#  butter: -0.0958
#  2327564d: -0.0958
#  clfa0py5lm: -0.0958
#  adjuster: -0.0958
#  mutual: -0.0958
#  86pknkchmr: -0.0958
#  fdjuyvzmrv: -0.0958
#  realised: -0.0958
#  beyond: -0.0958
#  riwup1rbhu: -0.0958
#  russaky89: -0.0958
#  releases: -0.0958
#  indyfest: -0.0958
#  four: -0.0958
#  transport: -0.0958
#  wcw: -0.0958
#  costing: -0.0958
#  apiece: -0.0958
#  causing: -0.0958
#  luv: -0.0958
#  v1sfllowgh: -0.0958
#  lobbied: -0.0958
#  dtdidinqyf: -0.0958
#  dnb: -0.0958
#  bg: -0.0958
#  lil: -0.0958
#  tru: -0.0958
#  cavb7pgepv: -0.0958
#  motordom: -0.0958
#  overtook: -0.0958
#  xv: -0.0958
#  filled: -0.0958
#  visionzero: -0.0958
#  entered: -0.0958
#  brainless: -0.0958
#  kristindavis: -0.0958
#  chem: -0.0958
#  ypvjgzqqqb: -0.0958
#  yzzxxknism: -0.0958
#  creel: -0.0958
#  outta: -0.0958
#  truestory: -0.0958
#  h9fsiaxv3q: -0.0958
#  time: -0.0958
#  winston: -0.0958
#  zzsee5hipm: -0.0958
#  squirrel: -0.0958
#  reap: -0.0958
#  moron: -0.0958
#  parked: -0.0958
#  modestmouseremix: -0.0958
#  hilarious: -0.0958
#  wireless: -0.0958
#  k3mnk9hnz5: -0.0958
#  garden: -0.0958
#  winning: -0.0958
#  nickscomics: -0.0958
#  hazards: -0.0958
#  darkness: -0.0958
#  fashion: -0.0958
#  lfw4kuukem: -0.0958
#  zw5jp46v5k: -0.0958
#  wealthy: -0.0958
#  aftershock_delo: -0.0958
#  scuf: -0.0958
#  smash: -0.0958
#  reads: -0.0958
#  hashtags: -0.0958
#  links: -0.0958
#  location: -0.0958
#  objective: -0.0958
#  strickskin: -0.0958
#  zumiez: -0.0958
#  crabbycale: -0.0958
#  dylanmcclure55: -0.0958
#  reunite: -0.0958
#  zachlowe_nba: -0.0958
#  v1mtr517ue: -0.0958
#  annoying: -0.0958
#  fxux987vzx: -0.0958
#  constantly: -0.0958
#  vannuyscouncil: -0.0958
#  nuys: -0.0958
#  1ki8lgvay4: -0.0958
#  ghetto: -0.0958
#  anp9g6njfd: -0.0958
#  acfi2rhz4n: -0.0958
#  scourge: -0.0958
#  selling: -0.0958
#  1017: -0.0958
#  lw9o2kdk18: -0.0958
#  ryobyqjfce: -0.0958
#  farmr: -0.0958
#  fanged: -0.0958
#  foragesecret: -0.0958
#  mart: -0.0958
#  morels: -0.0958
#  bitches: -0.0958
#  mushroom: -0.0958
#  photoshop: -0.0958
#  whedonesque: -0.0958
#  ambleside: -0.0958
#  kisses: -0.0958
#  round: -0.0958
#  soak: -0.0958
#  q0jhdcu6ly: -0.0958
#  chill: -0.0958
#  inning: -0.0958
#  sundays: -0.0958
#  skies: -0.0958
#  alisonannyoung: -0.0958
#  nurse: -0.0958
#  your: -0.0958
#  testy: -0.0958
#  valdes1978: -0.0958
#  seasonfrom: -0.0958
#  onshit: -0.0958
#  meter: -0.0958
#  happy: -0.0958
#  springs: -0.0958
#  itsnasb: -0.0958
#  igwstttkwk: -0.0958
#  thejenmorillo: -0.0958
#  omnbatjeao: -0.0958
#  lenkaiswaifu: -0.0958
#  x1402: -0.0958
#  korea: -0.0958
#  autismawareness: -0.0958
#  retro: -0.0958
#  woah: -0.0958
#  yumiko: -0.0958
#  engineshed: -0.0958
#  upwards: -0.0958
#  exactly: -0.0958
#  jw6fnnssxt: -0.0958
#  appreciate: -0.0958
#  4zaztb19qe: -0.0958
#  fantasticfour: -0.0958
#  k_matako_bot: -0.0958
#  ceo: -0.0958
#  explains: -0.0958
#  realdonaldtrump: -0.0958
#  compliant: -0.0958
#  animals: -0.0958
#  every: -0.0958
#  plmiwofpom: -0.0958
#  want: -0.0958
#  quote: -0.0958
#  oi6cmagasi: -0.0958
#  williams: -0.0958
#  mnh6fxhodb: -0.0958
#  hip: -0.0958
#  elbow: -0.0958
#  kabwandi_: -0.0958
#  profit: -0.0958
#  voted: -0.0958
#  gnzwxqktam: -0.0958
#  bq8kyi7gng: -0.0958
#  cutlery: -0.0958
#  robertwelch: -0.0958
#  smug: -0.0958
#  priceless: -0.0958
#  dryer: -0.0958
#  transit: -0.0958
#  4onvxncz8w: -0.0958
#  tnggxnm6k8: -0.0958
#  restricted: -0.0958
#  wj0u59mppb: -0.0958
#  democrats: -0.0958
#  zippednews: -0.0958
#  goin: -0.0958
#  wee: -0.0958
#  crackdown: -0.0958
#  mixtape: -0.0958
#  insomniacs: -0.0958
#  uungrqougn: -0.0958
#  invented: -0.0958
#  enqdfbjump: -0.0958
#  ucawg59ulj: -0.0958
#  cope: -0.0958
#  smaug: -0.0958
#  ooh: -0.0958
#  ahead: -0.0958
#  infosec: -0.0958
#  ew5wzc07fo: -0.0958
#  david: -0.0958
#  he: -0.0958
#  hi: -0.0958
#  fans: -0.0958
#  policy: -0.0958
#  gt: -0.0958
#  sound: -0.0958
#  letters: -0.0958
#  makes: -0.0958
#  chewing: -0.0958
#  awesome: -0.0958
#  ways: -0.0958
#  announcement: -0.0958
#  led: -0.0958
#  mayhem: -0.0958
#  bar: -0.0958
#  the: -0.0639
#  quiz: -0.0639
#  raiders: -0.0639
#  thing: -0.0639
#  07: -0.0639
#  low: -0.0639
#  and: -0.0639
#  spit: -0.0639
#  6craekc9wb: -0.0639
#  lovelylikelaura: -0.0639
#  baby: -0.0639
#  bayelsa: -0.0639
#  total: -0.0639
#  becca_caitlyn99: -0.0639
#  barn: -0.0639
#  front: -0.0639
#  fine: -0.0639
#  across: -0.0639
#  gcdxydbsc4: -0.0639
#  mystical: -0.0639
#  qadufo8zxg: -0.0639
#  plotted: -0.0639
#  oldest: -0.0639
#  donthate: -0.0639
#  freedom: -0.0639
#  follow: -0.0639
#  _explicitpretty: -0.0639
#  fifa16: -0.0639
#  ap9jbrpmqg: -0.0639
#  press: -0.0639
#  modernize: -0.0639
#  startrek: -0.0639
#  a2e6dcsk88: -0.0639
#  rhode: -0.0639
#  tos: -0.0639
#  lining: -0.0639
#  mizuta: -0.0639
#  gl4mcax0ny: -0.0639
#  nother: -0.0639
#  favorite: -0.0639
#  kshsgwghfj: -0.0639
#  helpme: -0.0639
#  dilawri: -0.0639
#  vancouver: -0.0639
#  disgusting: -0.0639
#  cycle: -0.0639
#  vg7jnah0iw: -0.0639
#  ticketed: -0.0639
#  nottingham: -0.0639
#  km8ucihrrn: -0.0639
#  mwwwowcayo: -0.0639
#  dq: -0.0639
#  f9j3l2yjl4: -0.0639
#  venezuela: -0.0639
#  alliance: -0.0639
#  regime: -0.0639
#  reject: -0.0639
#  eqjcpwilvn: -0.0639
#  assad: -0.0639
#  initiative: -0.0639
#  jim: -0.0639
#  guaranteed: -0.0639
#  fejs0bu0sq: -0.0639
#  logic: -0.0639
#  contemplating: -0.0639
#  alves: -0.0639
#  hurled: -0.0639
#  improved: -0.0639
#  azimel: -0.0639
#  nuked: -0.0639
#  deceased: -0.0639
#  sent: -0.0639
#  violators: -0.0639
#  uu64wfg17m: -0.0639
#  scientist: -0.0639
#  humid: -0.0639
#  rawfoodbliss: -0.0639
#  flared: -0.0639
#  patch: -0.0639
#  forehead: -0.0639
#  tbs: -0.0639
#  wayne: -0.0639
#  extract: -0.0639
#  oli: -0.0639
#  4kopkcyvtt: -0.0639
#  8hgcbxukz0: -0.0639
#  jannet2208: -0.0639
#  sergiopiaggio: -0.0639
#  player: -0.0639
#  hole: -0.0639
#  golf: -0.0639
#  brightly: -0.0639
#  wi: -0.0639
#  sonofliberty357: -0.0639
#  post: -0.0639
#  illuminated: -0.0639
#  stuffin: -0.0639
#  ae9cpiexak: -0.0639
#  jackass: -0.0639
#  chefs: -0.0639
#  kevin: -0.0639
#  deserve: -0.0639
#  pastures: -0.0639
#  drob: -0.0639
#  bat: -0.0639
#  tan: -0.0639
#  d9xvuvp9s6: -0.0639
#  icrgseagya: -0.0639
#  hxox7o42rq: -0.0639
#  studio: -0.0639
#  kpvymhm2ub: -0.0639
#  old: -0.0639
#  bigburgerboi55: -0.0639
#  spartans: -0.0639
#  crushing: -0.0639
#  footballs: -0.0639
#  iglnqpgbnw: -0.0639
#  ali: -0.0639
#  newåêheights: -0.0639
#  booradleyvancullen: -0.0639
#  aoesbvns45: -0.0639
#  depth: -0.0639
#  x1434: -0.0639
#  bc: -0.0639
#  inspi: -0.0639
#  dodxi41y1cåêis: -0.0639
#  lyrically: -0.0639
#  jywfygclhm: -0.0639
#  etc: -0.0639
#  hlmyaanrc9: -0.0639
#  coaster: -0.0639
#  damaged: -0.0639
#  qyu8grorq1: -0.0639
#  hadn: -0.0639
#  markets: -0.0639
#  bunch: -0.0639
#  gog: -0.0639
#  magog: -0.0639
#  jason: -0.0639
#  pic: -0.0639
#  dinosaurdracula: -0.0639
#  vi: -0.0639
#  dajaal: -0.0639
#  remorse: -0.0639
#  irhh2gvsed: -0.0639
#  ahamedis: -0.0639
#  messiah: -0.0639
#  incase: -0.0639
#  qu8s89pvvt: -0.0639
#  58qrugzvg0: -0.0639
#  jump: -0.0639
#  1pflm532mg: -0.0639
#  birthday: -0.0639
#  alas: -0.0639
#  remembered: -0.0639
#  graveyard: -0.0639
#  6pagjqfbzk: -0.0639
#  qzizelxbyr: -0.0639
#  vaccines: -0.0639
#  horowitz: -0.0639
#  publicizing: -0.0639
#  retweet: -0.0639
#  n5vrffrbo3: -0.0639
#  jsuhupz6vp: -0.0639
#  doubleghats: -0.0639
#  person: -0.0639
#  ootd: -0.0639
#  futurea: -0.0639
#  drfkarlz1d: -0.0639
#  totalitarian: -0.0639
#  employs: -0.0639
#  literature: -0.0639
#  corii: -0.0639
#  wishlist: -0.0639
#  hgedwxtdjn: -0.0639
#  spoil: -0.0639
#  l3gizrucy4: -0.0639
#  os1wjrvx5c: -0.0639
#  alex: -0.0639
#  wc: -0.0639
#  weebly: -0.0639
#  cnnbrk: -0.0639
#  mofanon: -0.0639
#  arsonist: -0.0639
#  blackburns: -0.0639
#  kadiegrr: -0.0639
#  aka: -0.0639
#  apartment: -0.0639
#  pll: -0.0639
#  meganbee92: -0.0639
#  brace: -0.0639
#  hexpc77otn: -0.0639
#  depressed: -0.0639
#  mflrvbh4qa: -0.0639
#  ranefihbuk: -0.0639
#  cable: -0.0639
#  tangled: -0.0639
#  traffic: -0.0639
#  donnelly: -0.0639
#  motivated: -0.0639
#  yn6nxoucr1: -0.0639
#  ek6kyhxpe9: -0.0639
#  breaches: -0.0639
#  btw: -0.0639
#  pilots: -0.0639
#  yourself: -0.0639
#  error: -0.0639
#  am: -0.0639
#  i0tvl15coz: -0.0639
#  tape: -0.0639
#  jewish: -0.0639
#  igtxhapo0k: -0.0639
#  lighter: -0.0639
#  website: -0.0639
#  17: -0.0639
#  physical: -0.0639
#  feel: -0.0639
#  they: -0.0639
#  certificates: -0.0639
#  safes: -0.0639
#  kmdqm3nlns: -0.0639
#  kasiakosek: -0.0639
#  circle: -0.0639
#  footage: -0.0639
#  inevitable: -0.0639
#  2014: -0.0639
#  wbcshirl2: -0.0639
#  cufi: -0.0639
#  doessnt: -0.0639
#  jews: -0.0639
#  rejoice: -0.0639
#  4arwwrzpsr: -0.0639
#  ect: -0.0639
#  convert: -0.0639
#  mkjq9yfmp8: -0.0639
#  calamities: -0.0639
#  emotions: -0.0639
#  sportinggoods: -0.0639
#  nr8jjmpmos: -0.0639
#  jacket: -0.0639
#  jvai5vkmsy: -0.0639
#  psychologist: -0.0639
#  lgglf5yrme: -0.0639
#  school: -0.0639
#  nafeezahmed: -0.0639
#  scynic1: -0.0639
#  sirtophamhat: -0.0639
#  jeremyduns: -0.0639
#  rights: -0.0639
#  cafe: -0.0639
#  supportive: -0.0639
#  economically: -0.0639
#  thursday: -0.0639
#  lw2fglrgxb: -0.0639
#  300m: -0.0639
#  pqslug4jk5: -0.0639
#  surprised: -0.0639
#  place: -0.0639
#  kodiak: -0.0639
#  thereisonlysex: -0.0639
#  robertcalifornia: -0.0639
#  fallacy: -0.0639
#  ending: -0.0639
#  advertise: -0.0639
#  opal: -0.0639
#  spinning: -0.0639
#  d12r8xpshy: -0.0639
#  hhpvsatqxn: -0.0639
#  925: -0.0639
#  danisnotonfire: -0.0639
#  gemstone: -0.0639
#  r1354: -0.0639
#  morganite: -0.0639
#  feelings: -0.0639
#  economic: -0.0639
#  garbage: -0.0639
#  grill: -0.0639
#  goals: -0.0639
#  actual: -0.0639
#  battery: -0.0639
#  needs: -0.0639
#  version: -0.0639
#  uniform: -0.0639
#  pieces: -0.0639
#  make: -0.0639
#  bored: -0.0639
#  heights: -0.0639
#  cigs: -0.0639
#  tray: -0.0639
#  willing: -0.0639
#  breath: -0.0639
#  odds: -0.0639
#  feminists: -0.0639
#  bistro: -0.0639
#  lnpscadaxr: -0.0639
#  salvi: -0.0639
#  03: -0.0639
#  earners: -0.0639
#  gained: -0.0639
#  plague: -0.0639
#  torch: -0.0639
#  suffer: -0.0639
#  favs: -0.0639
#  drug: -0.0639
#  steal: -0.0639
#  gzmoblsjxu: -0.0639
#  niall: -0.0639
#  ham: -0.0639
#  caesars: -0.0639
#  thetxi: -0.0639
#  gunnersfan89: -0.0639
#  wwa: -0.0639
#  1d: -0.0639
#  relegation: -0.0639
#  gbbo: -0.0639
#  5cgtqfk2ur: -0.0639
#  ash: -0.0639
#  thy: -0.0639
#  expand: -0.0639
#  sjoeing76t: -0.0639
#  paulista: -0.0639
#  chat: -0.0639
#  ducks: -0.0639
#  looting: -0.0639
#  goku: -0.0639
#  ytkxwpyihg: -0.0639
#  westward: -0.0639
#  handle: -0.0639
#  if5rogfjri: -0.0639
#  regent: -0.0639
#  wolves: -0.0639
#  vlnjnolnme: -0.0639
#  browseråêhijacker: -0.0639
#  dogger: -0.0639
#  witch: -0.0639
#  tryna: -0.0639
#  rapper: -0.0639
#  towing: -0.0639
#  orchid: -0.0639
#  8400: -0.0639
#  vibrates: -0.0639
#  metre: -0.0639
#  hrsfa8zuji: -0.0639
#  jailbreak: -0.0639
#  swingman: -0.0639
#  ig: -0.0639
#  peanut: -0.0639
#  idek: -0.0639
#  shipsxanchors: -0.0639
#  p93s2rfhx6: -0.0639
#  jersey: -0.0639
#  48tpnmbjvg: -0.0639
#  stefano: -0.0639
#  adidas: -0.0639
#  hackers: -0.0639
#  uribe: -0.0639
#  pluto: -0.0639
#  t81oayjowc: -0.0639
#  gix1gaynxz: -0.0639
#  name: -0.0639
#  lulgzimbestpicts: -0.0639
#  dieanpink95: -0.0639
#  anyways: -0.0639
#  buddy: -0.0639
#  under: -0.0639
#  5n4husewly: -0.0639
#  veggies: -0.0639
#  bioter: -0.0639
#  gan14pw9tg: -0.0639
#  fruits: -0.0639
#  freeze: -0.0639
#  theboyofmasks: -0.0639
#  tested: -0.0639
#  mark: -0.0639
#  speaking: -0.0639
#  fgcu: -0.0639
#  2011: -0.0639
#  concluded: -0.0639
#  yu_nita99: -0.0639
#  charity: -0.0639
#  manor: -0.0639
#  met0mtpr3s: -0.0639
#  downright: -0.0639
#  roh3: -0.0639
#  quartz: -0.0639
#  tries: -0.0639
#  otratmetlife: -0.0639
#  metlife: -0.0639
#  grlxurko8d: -0.0639
#  sep: -0.0639
#  fort: -0.0639
#  ops: -0.0639
#  remove: -0.0639
#  balanced: -0.0639
#  divided: -0.0639
#  gotham: -0.0639
#  bcs: -0.0639
#  ìñ1: -0.0639
#  locke_wiggins: -0.0639
#  agrees: -0.0639
#  pills: -0.0639
#  7s9nm1fict: -0.0639
#  remade: -0.0639
#  elm: -0.0639
#  qchv3jqovk: -0.0639
#  gc0udfnfgg: -0.0639
#  auntiedote: -0.0639
#  akarb74: -0.0639
#  shovel: -0.0639
#  idm: -0.0639
#  rioslade: -0.0639
#  expirehc: -0.0639
#  hvwkjqxxyt: -0.0639
#  sleepjunkies: -0.0639
#  forgiven: -0.0639
#  campbell: -0.0639
#  crobscarla: -0.0639
#  mere: -0.0639
#  th: -0.0639
#  sharing: -0.0639
#  proven: -0.0639
#  n4neuiyt2k: -0.0639
#  aggressive: -0.0639
#  8015: -0.0639
#  perkpearl: -0.0639
#  fb: -0.0639
#  rewatchingthepilot: -0.0639
#  lsjowgyvqh: -0.0639
#  sworn: -0.0639
#  teamscorpion: -0.0639
#  donations: -0.0639
#  resemblance: -0.0639
#  chikislizeth08: -0.0639
#  roger: -0.0639
#  footed: -0.0639
#  packs: -0.0639
#  troyslaby22: -0.0639
#  ireland: -0.0639
#  lennonparham: -0.0639
#  customs: -0.0639
#  l9udest: -0.0639
#  gilmoreguysshow: -0.0639
#  milk: -0.0639
#  qmo1txxdkj: -0.0639
#  strange: -0.0639
#  acmilan: -0.0639
#  jessica_stclair: -0.0639
#  ovlet0gdqm: -0.0639
#  whoops: -0.0639
#  centers: -0.0639
#  mccain: -0.0639
#  ihave44episodesofgg: -0.0639
#  bv: -0.0639
#  3am: -0.0639
#  aust: -0.0639
#  till: -0.0639
#  pajamas: -0.0639
#  nojoke: -0.0639
#  podcast: -0.0639
#  hhs: -0.0639
#  w6yu7qs4cv: -0.0639
#  photographed: -0.0639
#  jnromse1z2: -0.0639
#  e61x9y65qd: -0.0639
#  washington: -0.0639
#  publish: -0.0639
#  1620: -0.0639
#  selects: -0.0639
#  exyr6c5qpu: -0.0639
#  g0q0bzbjli: -0.0639
#  floor: -0.0639
#  wider: -0.0639
#  militarydotcom: -0.0639
#  upper: -0.0639
#  therapies: -0.0639
#  variety: -0.0639
#  eggs: -0.0639
#  creates: -0.0639
#  capicapricapri: -0.0639
#  performance: -0.0639
#  farts: -0.0639
#  soonersportstv: -0.0639
#  brento_bento: -0.0639
#  staff: -0.0639
#  catcher: -0.0639
#  flatts: -0.0639
#  2o7eva1coe: -0.0639
#  cxb55h37jn: -0.0639
#  pe2r3ln16o: -0.0639
#  samajp32: -0.0639
#  tone: -0.0639
#  demon: -0.0639
#  vortex: -0.0639
#  humor: -0.0639
#  h6tyysgr30: -0.0639
#  rascal: -0.0639
#  ageekyfangirl14: -0.0639
#  oiywrzl79z: -0.0639
#  wha: -0.0639
#  kyle: -0.0639
#  omega: -0.0639
#  kinetic: -0.0639
#  zimbabwe: -0.0639
#  littlewomenla: -0.0639
#  modest: -0.0639
#  magisters: -0.0639
#  growingupspoiled: -0.0639
#  jasmines: -0.0639
#  noah: -0.0639
#  mortified: -0.0639
#  forgive: -0.0639
#  newsarama: -0.0639
#  cecilthelion: -0.0639
#  explores: -0.0639
#  uwobuuw2mk: -0.0639
#  religion: -0.0639
#  pulse: -0.0639
# ...
#  estimated: 0.1597
#  stay: 0.1597
#  see: 0.1597
#  kindermorgan: 0.1597
#  parade: 0.1597
#  in: 0.1597
#  wounds: 0.1597
#  drunk: 0.1597
#  buddys: 0.1597
#  outside: 0.1597
#  omg: 0.1597
#  wxhmp5ppjq: 0.1597
#  might: 0.1597
#  em: 0.1597
#  360wisenews: 0.1597
#  exploded: 0.1597
#  fear: 0.1597
#  trouble: 0.1597
#  don: 0.1597
#  is: 0.1597
#  canada: 0.1916
#  michigan: 0.1916
#  area: 0.1916
#  blah: 0.1916
#  political: 0.1916
#  tho: 0.1916
#  concert: 0.1916
#  tremor: 0.1916
#  those: 0.1916
#  nuff: 0.1916
#  dave: 0.1916
#  an3w16c8f6: 0.1916
#  jonathan: 0.1916
#  happen: 0.1916
#  j4ggmkiney: 0.1916
#  forbesasia: 0.1916
#  house: 0.1916
#  central: 0.1916
#  p1amginsys: 0.1916
#  couches: 0.1916
#  seal: 0.1916
#  pilot: 0.1916
#  eudrylantiqua: 0.1916
#  pl2vzlrkvk: 0.1916
#  deserves: 0.1916
#  sidelines: 0.1916
#  initial: 0.1916
#  byvubg0wye: 0.1916
#  investigators: 0.1916
#  omfg: 0.1916
#  appropriation: 0.1916
#  acid: 0.1916
#  issued: 0.1916
#  hkm3rtd4zf: 0.1916
#  decisionsondecisions: 0.1916
#  7dyoglhmre: 0.1916
#  jilfbr0ufp: 0.1916
#  deliver: 0.1916
#  yyc: 0.1916
#  honestly: 0.1916
#  defects: 0.1916
#  shit: 0.1916
#  ukraine: 0.1916
#  tnn: 0.1916
#  9lo0hzwjpz: 0.1916
#  darrellissa: 0.1916
#  called: 0.1916
#  helene_yancey: 0.1916
#  arrested: 0.1916
#  48h3tlvlxr: 0.1916
#  coast: 0.1916
#  ghostwriter: 0.1916
#  helene: 0.1916
#  nowplay: 0.1916
#  r5bxzzhxkm: 0.1916
#  mid: 0.1916
#  library: 0.1916
#  palestinian: 0.1916
#  greenharvard: 0.1916
#  recalls: 0.1916
#  streak: 0.1916
#  walls: 0.1916
#  wholesale: 0.1916
#  54: 0.1916
#  trials: 0.1916
#  blows: 0.1916
#  obedience: 0.1916
#  refugee: 0.1916
#  main: 0.1916
#  alexandrian: 0.1916
#  damages: 0.1916
#  wreak: 0.1916
#  seatbelt: 0.1916
#  njqv45nds2: 0.1916
#  times: 0.1916
#  snap: 0.1916
#  81neizeknm: 0.1916
#  frog: 0.1916
#  2002: 0.1916
#  acts: 0.1916
#  shelter: 0.1916
#  several: 0.1916
#  ledofficial1: 0.1916
#  cm7hqwwulz: 0.1916
#  sweets: 0.1916
#  samples: 0.1916
#  requests: 0.1916
#  kdwazhqtov: 0.1916
#  question: 0.1916
#  west: 0.1916
#  saintrobinho86: 0.1916
#  pays: 0.1916
#  demonstrated: 0.1916
#  systems: 0.1916
#  picture: 0.1916
#  apaz: 0.1916
#  hollywarnexx: 0.1916
#  anytime: 0.1916
#  ashayo: 0.1916
#  owner: 0.1916
#  eruption: 0.1916
#  coffee: 0.1916
#  ships: 0.1916
#  didn: 0.1916
#  dealbreaker: 0.1916
#  comparison: 0.1916
#  haydnexists: 0.1916
#  higher: 0.1916
#  booth: 0.1916
#  pulls: 0.1916
#  thankful: 0.1916
#  fart: 0.1916
#  kappa: 0.1916
#  live_workshop: 0.1916
#  thanks: 0.1916
#  severe: 0.1916
#  gunman: 0.1916
#  hyperbole: 0.1916
#  saintsfc: 0.1916
#  nws: 0.1916
#  qp6q8rs8on: 0.1916
#  spin: 0.1916
#  jungle: 0.1916
#  23rd: 0.1916
#  basic: 0.1916
#  cubs: 0.1916
#  defs: 0.1916
#  came: 0.1916
#  beckyfeigin: 0.1916
#  0gidg9u45j: 0.1916
#  reriellechan: 0.1916
#  lich: 0.1916
#  neighborhood: 0.1916
#  c1njpli5or: 0.1916
#  friend50: 0.1916
#  hy5pbe12tm: 0.1916
#  invasion: 0.1916
#  snowywolf5: 0.1916
#  thegreenparty: 0.1916
#  01: 0.1916
#  qzdqrbr4lh: 0.1916
#  rand: 0.1916
#  kgkz50q8tk: 0.1916
#  cdcgov: 0.1916
#  blast: 0.1916
#  using: 0.1916
#  3mtwh0jjns: 0.1916
#  philly: 0.1916
#  donald: 0.1916
#  slowly: 0.1916
#  tezltqeyw2: 0.1916
#  young: 0.1916
#  hurricane_surge: 0.1916
#  chubbysquirrel_: 0.1916
#  33333: 0.1916
#  victims: 0.1916
#  detonate: 0.1916
#  worth: 0.1916
#  survivor: 0.1916
#  redo: 0.1916
#  triple: 0.1916
#  internally: 0.1916
#  ayyy: 0.1916
#  please: 0.1916
#  september: 0.1916
#  acrylic: 0.1916
#  boyinahorsemask: 0.1916
#  panda: 0.1916
#  x17fubqbgg: 0.1916
#  mate: 0.1916
#  easlgea1b7: 0.1916
#  catches: 0.1916
#  nah: 0.1916
#  aircraft: 0.1916
#  update: 0.1916
#  harper: 0.1916
#  refugees: 0.1916
#  pckf0nl2yn: 0.1916
#  true: 0.1916
#  12000: 0.1916
#  lunch: 0.1916
#  bettyfreedoms: 0.1916
#  abninfvet: 0.1916
#  gf: 0.1916
#  valleywx: 0.1916
#  nigerian: 0.1916
#  seems: 0.1916
#  condemnation: 0.1916
#  unawares: 0.1916
#  hunt: 0.1916
#  deluged: 0.1916
#  battlefield: 0.1916
#  canyon: 0.1916
#  server: 0.1916
#  un: 0.1916
#  amid: 0.1916
#  gun: 0.1916
#  dutch: 0.1916
#  crane: 0.1916
#  9000: 0.1916
#  heyitsepark: 0.1916
#  abouts: 0.1916
#  essexweather: 0.1916
#  tweet4taiji: 0.1916
#  glenstannard: 0.1916
#  worship: 0.1916
#  superstitions: 0.1916
#  freak: 0.1916
#  taking: 0.1916
#  senator: 0.1916
#  canoe: 0.1916
#  cut: 0.2555
#  shape: 0.2555
#  wmata: 0.2555
#  rush: 0.2555
#  bullets: 0.2555
#  985dwwpdet: 0.2555
#  wveo9ed10e: 0.2555
#  129: 0.2555
#  crews: 0.2555
#  arm: 0.2555
#  injured: 0.2555
#  cqyvfr4ucy: 0.2555
#  c0slabbp7j: 0.2555
#  xspqdoriqj: 0.2555
#  wackos: 0.2555
#  texas: 0.2555
#  displaced: 0.2555
#  arsenal: 0.2555
#  aug: 0.2555
#  satanaofhell: 0.2555
#  dreamy: 0.2555
#  hazardous: 0.2555
#  trains: 0.2555
#  theyre: 0.2555
#  9naw3qoqol: 0.2555
#  njlqrqcnl9: 0.2555
#  set: 0.2555
#  v8aftd9zez: 0.2555
#  alil: 0.2555
#  skin: 0.2555
#  officials: 0.2555
#  hijacker: 0.2555
#  fam: 0.2555
#  omfgv9ma1w: 0.2555
#  abc: 0.2555
#  plane: 0.2555
#  imagine: 0.2555
#  ready: 0.2555
#  point: 0.2555
#  tides: 0.2555
#  8jxql8cv8z: 0.2555
#  survivors: 0.2555
#  depressing: 0.2555
#  leader: 0.2555
#  apollo: 0.2555
#  watch: 0.2555
#  stealing: 0.2555
#  range: 0.2555
#  simply: 0.2555
#  adamrubinespn: 0.2555
#  bound: 0.2555
#  bilsko: 0.2555
#  libya: 0.2555
#  humofthecity: 0.2555
#  godsfirstson1: 0.2555
#  humanity: 0.2555
#  practically: 0.2555
#  cab: 0.2555
#  suddenly: 0.2555
#  pyrbliss: 0.2555
#  heat: 0.2555
#  dolphin: 0.2555
#  meeting: 0.2555
#  mo: 0.2555
#  clearly: 0.2555
#  hope: 0.2555
#  sport_en: 0.2555
#  smoke: 0.2555
#  theashes: 0.2555
#  control: 0.2555
#  sake: 0.2555
#  crisis: 0.2555
#  case: 0.2555
#  awareness: 0.2555
#  talking: 0.2555
#  chick: 0.2555
#  forget: 0.2555
#  peacefully: 0.2555
#  rep: 0.2555
#  call: 0.2555
#  101: 0.2555
#  myanmar: 0.2555
#  screaming: 0.2555
#  wild: 0.2555
#  hostages: 0.2555
#  nuclear: 0.2555
#  region: 0.2555
#  oneheartonemindonecss: 0.2555
#  aid: 0.2555
#  sevenfigz: 0.2555
#  20b3pnqxmd: 0.2555
#  kopiteluke1892: 0.2555
#  wvobvvtxkg: 0.2555
#  murderer: 0.2555
#  aod2ftbmgu: 0.2555
#  _chelsdelong12: 0.2555
#  kendra_leigh13: 0.2555
#  crushed: 0.2555
#  sick: 0.2555
#  liberal: 0.2555
#  ambulance: 0.2555
#  nd: 0.2874
#  twpl0nl8cx: 0.2874
#  incident: 0.2874
#  bucs: 0.2874
#  injury: 0.2874
#  michael5sos: 0.2874
#  coaches: 0.2874
#  legionnaires: 0.2874
#  hadnt: 0.2874
#  butgod: 0.2874
#  smh: 0.2874
#  israel: 0.2874
#  ltmgdp6jaf: 0.2874
#  emmychappy: 0.2874
#  opens: 0.2874
#  foxnews: 0.2874
#  police: 0.2874
#  agents: 0.2874
#  debris: 0.2874
#  ten: 0.2874
#  obligations: 0.2874
#  tank: 0.2874
#  grateful: 0.2874
#  afternoon: 0.2874
#  mets: 0.2874
#  pianohands: 0.2874
#  taxis: 0.2874
#  dm0uupqgwy: 0.2874
#  riveeeeeer: 0.2874
#  iiii: 0.2874
#  east: 0.2874
#  fireball: 0.2874
#  bjojvm0pjx: 0.2874
#  whoc7lhb5f: 0.2874
#  odv3rqs8ju: 0.2874
#  3drsmxw3cr: 0.2874
#  txetcysm1h: 0.2874
#  report: 0.2874
#  nails: 0.2874
#  california: 0.2874
#  mnpdnashville: 0.2874
#  bill_roose: 0.2874
#  situation: 0.2874
#  continues: 0.2874
#  bomber: 0.2874
#  helicopter: 0.2874
#  israeli: 0.2874
#  ryans: 0.2874
#  adip0unxhu: 0.2874
#  mattburgener: 0.2874
#  crime: 0.2874
#  todd_calfee: 0.2874
#  ol: 0.2874
#  pacific: 0.2874
#  murderous: 0.2874
#  victory: 0.2874
#  waited: 0.2874
#  lost: 0.2874
#  serious: 0.2874
#  were: 0.2874
#  cloudy_goldrush: 0.2874
#  _301dc: 0.2874
#  narrowly: 0.2874
#  kellkane: 0.2874
#  unrealtouch: 0.2874
#  atomic: 0.2874
#  izjk6kpwiz: 0.2874
#  survive: 0.2874
#  lion: 0.2874
#  devastation: 0.2874
#  crush: 0.2874
#  predict: 0.2874
#  dm: 0.2874
#  danger: 0.2874
#  ferguson: 0.2874
#  emergency: 0.2874
#  japan: 0.3194
#  murder: 0.3194
#  fllabzgcrc: 0.3194
#  prebreak: 0.3194
#  cards: 0.3194
#  apwxs5mm44: 0.3194
#  ds76lozlsu: 0.3194
#  insomnia: 0.3194
#  dothraki: 0.3194
#  cain: 0.3194
#  buses: 0.3194
#  quarter: 0.3194
#  badge: 0.3194
#  lucysforsale: 0.3194
#  eyesss: 0.3194
#  thruuu: 0.3194
#  ain: 0.3194
#  damn: 0.3194
#  dalailama: 0.3194
#  balcony: 0.3194
#  wrapped: 0.3194
#  calgary: 0.3194
#  fatalities: 0.3194
#  collapsed: 0.3194
#  evacuation: 0.3194
#  qj3pvgavn7: 0.3194
#  setting: 0.3194
#  c5u9qshhnb: 0.3194
#  weloveyoulouis: 0.3194
#  5qhoehe9hf: 0.3194
#  masturbates: 0.3194
#  swim: 0.3194
#  bagging: 0.3194
#  tackettdc: 0.3194
#  blink: 0.3194
#  d4c2iqirnu: 0.3194
#  jets: 0.3194
#  hea: 0.3194
#  wesleylowery: 0.3194
#  crawling: 0.3194
#  sleep: 0.3194
#  hoe: 0.3194
#  expect: 0.3194
#  buted: 0.3194
#  ina: 0.3194
#  towel: 0.3194
#  royals: 0.3194
#  talibans: 0.3194
#  kiranahmedd: 0.3194
#  quarterstaff: 0.3194
#  annihilating: 0.3194
#  yo: 0.3194
#  event: 0.3194
#  thunderstorm: 0.3194
#  toddyrockstar: 0.3194
#  jdtpirnm76: 0.3194
#  drowned: 0.3194
#  neon: 0.3194
#  councilscc: 0.3194
#  niiiice: 0.3194
#  hoo: 0.3194
#  woo: 0.3194
#  fully: 0.3194
#  here: 0.3194
#  bomb: 0.3194
#  comuiok3mp: 0.3513
#  zpxe3fmyng: 0.3513
#  0f8xa4ih1u: 0.3513
#  spill: 0.3513
#  weapons: 0.3513
#  umgd92wlja: 0.3513
#  g0r3zr1nqj: 0.3513
#  ouylwuixcs: 0.3513
#  famine: 0.3513
#  ehgtzhkan4: 0.3513
#  87efcbiczm: 0.3513
#  distance: 0.3513
#  s0eyq1wehe: 0.3513
#  choppas: 0.3513
#  squad: 0.3513
#  science: 0.3513
#  kpqk0c4g0m: 0.3513
#  forest: 0.3513
#  sb5r7shccj: 0.3513
#  bartender: 0.3513
#  ipod: 0.3513
#  nothing: 0.3513
#  heavy: 0.3513
#  externally: 0.3513
#  j2aqs5loxu: 0.3513
#  mh370: 0.3513
#  alextucker: 0.3513
#  urufusanragu: 0.3513
#  tatzfk63ch: 0.3513
#  disneyirh: 0.3513
#  rexyy: 0.3513
#  outs: 0.3513
#  riot: 0.3513
#  victim: 0.3513
#  annihilated: 0.3513
#  tomorrow: 0.3513
#  war: 0.3513
#  butt: 0.3513
#  mfs: 0.3513
#  yankees: 0.3513
#  xrp0rtkffj: 0.3513
#  sophiewisey: 0.3513
#  near: 0.3513
#  fatality: 0.3513
#  fitzgerald: 0.3513
#  georgefoster72: 0.3513
#  edmund: 0.3513
#  village: 0.3513
#  hostage: 0.3513
#  muslims: 0.3513
#  sinkhole: 0.3513
#  kemal_atlay: 0.3513
#  blizzard: 0.3513
#  gas: 0.3513
#  flames: 0.3513
#  done: 0.3513
#  outbreak: 0.3832
#  teq7sri57p: 0.3832
#  harms: 0.3832
#  suicide: 0.3832
#  daviesmutia: 0.3832
#  sw1sbua3mn: 0.3832
#  devastated: 0.3832
#  shot: 0.3832
#  begins: 0.3832
#  apt: 0.3832
#  4vwsl2gfp0: 0.3832
#  gainesville: 0.3832
#  collision: 0.3832
#  tragedy: 0.3832
#  imaginable: 0.3832
#  mount_wario: 0.3832
#  kirafrog: 0.3832
#  lightening: 0.3832
#  jevhknjgbx: 0.3832
#  xxkhjysn0p: 0.3832
#  86rsyy2tng: 0.3832
#  sandstorm: 0.3832
#  hyider_ghost2: 0.3832
#  witter: 0.3832
#  something: 0.3832
#  wave: 0.3832
#  wtf: 0.3832
#  casualty: 0.3832
#  aubrey: 0.3832
#  tianta_: 0.3832
#  boxing: 0.3832
#  snowstorm: 0.3832
#  lordrsbiscuits: 0.3832
#  tiost8okvx: 0.3832
#  shadow: 0.3832
#  vygh2ni4ah: 0.3832
#  landslide: 0.3832
#  bleeding: 0.3832
#  allahsfinest12: 0.3832
#  katramsland: 0.3832
#  bit: 0.3832
#  sincere: 0.3832
#  davidvonderhaar: 0.3832
#  tyyfg4qqvm: 0.4152
#  disaster: 0.4152
#  xv3d9bpjhi: 0.4152
#  dies: 0.4152
#  bluebirddenver: 0.4152
#  nearly: 0.4152
#  suing: 0.4152
#  horrible: 0.4152
#  hail: 0.4152
#  fire: 0.4152
#  poor: 0.4152
#  mass: 0.4152
#  thirsty: 0.4152
#  train: 0.4152
#  jesus: 0.4152
#  peace: 0.4152
#  thee: 0.4152
#  __: 0.4152
#  peacetime: 0.4152
#  aware: 0.4152
#  accident: 0.4152
#  piprhys: 0.4152
#  thunder: 0.4152
#  truly_stings: 0.4152
#  smithsonian: 0.4152
#  terrorist: 0.4152
#  airplane: 0.4152
#  jrowah: 0.4471
#  hand: 0.4471
#  cos: 0.4471
#  rainstorm: 0.4471
#  temecafreeman: 0.4471
#  onto: 0.4471
#  x1392: 0.4471
#  leedsrouge: 0.4471
#  scene: 0.4471
#  moly: 0.4471
#  snow: 0.4471
#  mall: 0.4471
#  stab: 0.4471
#  iap4lwvqsw: 0.4471
#  flooding: 0.4471
#  striker: 0.4471
#  hurricane_dolce: 0.4471
#  fandom: 0.4471
#  weapon: 0.4471
#  hijacking: 0.4471
#  risks: 0.4471
#  annihilation: 0.4471
#  qkrltrd39b: 0.4790
#  tiggr_: 0.4790
#  to9viqoofv: 0.4790
#  riots: 0.4790
#  m19ivwrdkk: 0.4790
#  cyclone: 0.4790
#  prob: 0.4790
#  willienelson: 0.4790
#  gf5qjgoyci: 0.4790
#  burning: 0.4790
#  whirlwind: 0.4790
#  tornado: 0.5110
#  demons: 0.5110
#  explosion: 0.5110
#  collapse: 0.5110
#  deaths: 0.5110
#  volcano: 0.5110
#  evacuate: 0.5110
#  pikin: 0.5110
#  rioting: 0.5110
#  brooklyn: 0.5110
#  derailed: 0.5110
#  allen_enbot: 0.5429
#  itss_selenaluna: 0.5429
#  wildfire: 0.5429
#  extraordinaire: 0.5429
#  terrorism: 0.5429
#  pileq: 0.5429
#  chim: 0.5429
#  bioterrorism: 0.5429
#  flood: 0.5429
#  evacuated: 0.5429
#  ngkrzpza45: 0.5748
#  crash: 0.5748
#  hurricane_dame: 0.5748
#  nochilllukehammings: 0.5748
#  ucsudk3q1d: 0.5748
#  casualties: 0.5748
#  derailment: 0.6068
#  bombing: 0.6068
#  hailstorm: 0.6068
#  damage: 0.6068
#  hiroshima: 0.6387
#  fires: 0.6387
#  storm: 0.6387
#  mudslide: 0.6387
#  typhoon: 0.7026
#  floods: 0.7026
#  drought: 0.7345
#  hurricane: 0.7345
#  sunburned: 0.7664
#  captainn_morgan: 0.7984
#  earthquake: 0.8303
#  massacre: 0.8303

# %% [markdown]
# #### Deliverable 2.1
#
# Based on the training accuracy, do you conclude that the data are linearly separable? Why or why not?
#
# [your answer here]
#
# #### Deliverable 2.2
#
# Which feature most increases the likelihood that the tweet does not refer to a real disaster, and which feature most increases the likelihood that the tweet refers to a real disaster?
#
# [your answer here]

# %% [markdown]
# #### Deliverable 2.3
# One technique for improving the resulting model with perceptron (or stochastic gradient descent learning in general) is to take an average of the weight vectors learned at different iterations of the algorithm, rather than only using the final weights that minimize the loss. That is, calculate $\bar{\mathbf{w}} = \sum_{t=1}^T \mathbf{w}^{(t)}$ where $\mathbf{w}^{(t)}$ is the weight vector at iteration $t$ of the algorithm and $T$ is the number of iterations, and then use $\bar{\mathbf{w}}$ when making classifications on new data.
#
# To use this technique in your classifier, add the keyword argument `average=True` to the `SGDClassifier` function. Try it now using the cell below.
#
# Compare the initial training/test accuracies to the training/test accuracies after doing averaging. What happens? Why do you think averaging the weights from different iterations has this effect?

# %% [markdown]
# [your answer here]

# %% [markdown]
# ## Problem 3: Logistic regression [15 points]
#
# For this problem, create a new `SGDClassifier`, this time setting the `loss` argument to `'log'`, which will train a logistic regression classifier. Set `average=False` for the remaining problems.
#
# Once you have trained the classifier, you can use the `predict` function to get the classifications, as with perceptron. Additionally, logistic regression provides probabilities for the predictions. You can get the probabilities by calling the `predict_proba` function. This will give a list of two numbers; the first is the probability that the class is $0$ and the second is the probability that the class is $1$.
#
#
# For the first task, add the keyword argument `alpha` to the `SGDClassifier` function. This is the regularization strength, called $\lambda$ in lecture. If you don't specify `alpha`, it defaults to $0.0001$. Experiment with other values and see how this affects the outcome.
#
# #### Deliverable 3.1:
#
# Calculate the training and testing accuracy when `alpha` is one of $[0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0]$. Create a plot where the x-axis is `alpha` and the y-axis is accuracy, with two lines (one for training and one for testing). You can borrow the code from HW1 for generating plots in Python. Use [a log scale for the x-axis](https://matplotlib.org/examples/pylab_examples/log_demo.html) so that the `alpha` values are spaced evenly.
#
# [your solution should be plotted below]

# %%
# your code here

# %% [markdown]
# #### Deliverable 3.2
#
# Examine the classifier probabilities using the `predict_proba` function when training with different values of `alpha`. What do you observe? How does `alpha` affect the prediction probabilities, and why do you think this happens?
#
# [your answer here]
#
# #### Deliverable 3.2.1
#
# Now remove the `alpha` argument so that it goes back to the default value. We'll now look at the effect of the learning rate. By default, `sklearn` uses an "optimal" learning rate based on some heuristics that work well for many problems. However, it can be good to see how the learning rate can affect the algorithm.
#
# For this task, add the keyword argument `learning_rate` to the `SGDClassifier` function and set the value to `invscaling`. This defines the learning rate at iteration $t$ as: $\eta_t = \frac{\eta_0}{t^a}$, where $\eta_0$ and $a$ are both arguments you have to define in the `SGDClassifier` function, called `eta0` and `power_t`, respectively. Experiment with different values of `eta0` and `power_t` and see how they affect the number of iterations it takes the algorithm to converge. You will often find that it will not finish within the maximum of $1000$ iterations.

# %% [markdown]
# #### Deliverable 3.3:
#
# Fill in the table below with the number of iterations for values of `eta0` in $[10.0, 100.0, 1000.0, 10000.0]$ and values of `power_t` in $[0.5, 1.0, 2.0]$. You may find it easier to write python code that can output the markdown for the table, but if you do that place the output here. If it does not converge within the maximum number of iterations (set to $1000$ by `max_iter`), record $1000$ as the number of iterations. You will need to read the documentation for this class to learn how to recover the actual number of iterations before reaching the stopping criterion.
#
# | `eta0`   | `power_t` | # Iterations |
# |-----------|-----------|--------------|
# | $10.0$    | $0.5$     |              |
# | $10.0$    | $1.0$     |              |
# | $10.0$    | $2.0$     |              |
# | $100.0$   | $0.5$     |              |
# | $100.0$   | $1.0$     |              |
# | $100.0$   | $2.0$     |              |
# | $1000.0$  | $0.5$     |              |
# | $1000.0$  | $1.0$     |              |
# | $1000.0$  | $2.0$     |              |
# | $10000.0$ | $0.5$     |              |
# | $10000.0$ | $1.0$     |              |
# | $10000.0$ | $2.0$     |              |

# %% [markdown]
# #### Deliverable 3.4
#
# Describe how `eta0` and `power_t` affect the learning rate based on the formula (e.g., if you increase `power_t`, what will this do to the learning rate?), and connect this to what you observe in the table above.
#
# [your answer here]
#
# #### Deliverable 3.4.1
#
# Now remove the `learning_rate`, `eta0`, and `power_t` arguments so that the learning rate returns to the default setting. For this final task, we will experiment with how high the probabiity must be before an instance is classified as positive.
#
# The code below includes a function called `threshold` which takes as input the classification probabilities of the data (called `probs`, which is given by the function `predict_proba`) and a threshold (called `tau`, a scalar that should be a value between $0$ and $1$). It will classify each instance as $1$ if the probability of being $\textrm{Android}$ is greater than `tau`, otherwise it will classify the instance as $0$. Note that if you set `tau` to $0.5$, the `threshold` function should give you exactly the same output as the classifier `predict` function.
#
# You should find that increasing the threshold causes the accuracy to drop. This makes sense, because you are classifying some things as 0 even though it's more probable that they are 1. So why do this? Suppose you care more about accurately identifying the 1 tweets and you don't care as much about 0 tweets. You want to be confident that when you classify a tweet as 1 that it really is 1.
#
# There is a metric called _precision_ which measures something like accuracy but for one specific class. Whereas accuracy is the percentage of tweets that were correctly classified, the precision of 1 would be the percentage of tweets classified as 1 that were correctly classified. (In other words, the number of tweets classified as 1 whose correct label was 1, divided by the number of tweets classified as 1.)
#
# You can use the [`precision_score`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score) function from `sklearn` to calculate the precision. It works just like the `accuracy_score` function, except you have to add an additional keyword argument, `pos_label='Android'`, which tells it that $\textrm{Android}$ is the class you want to calculate the precision of.

# %%
# your answer here

# %% [markdown]
# #### Deliverable 3.5
#
# Calculate the testing precision when the value of `tau` for thresholding is one of $[0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99]$. Create a plot where the x-axis is `tau` and the y-axis is precision.
#
# [your solution should either be plotted below, or included in a separate PDF]

# %%
# use this function for deliverable 3.5
def threshold(probs, tau):
    return np.where(probs[:,0] > tau, 1, 0)

# your logistic regression code here

classifier = SGDClassifier(loss='log', max_iter=1000, tol=1.0e-12, random_state=123)
classifier.fit(X_train, Y_train)

# %% [markdown]
# #### Deliverable 3.6
#
# Describe what you observe with thresholding (e.g., what happens to precision as the threshold increases?), and explain why you think this happens.

# %% [markdown]
# [your answer here]

# %% [markdown]
# ## Problem 4: Sparse learning [5604: 5 points; 4604: +3 EC points]
#
# Add the `penalty` argument to `SGDClassifier` and set the value to `'l1'`, which tells the algorithm to use L1 regularization instead of the default L2. Recall from lecture that L1 regularization encourages weights to stay at exactly $0$, resulting in a more "sparse" model than L2. You should see this effect if you examine the values of `classifier.coef_`.
#
# #### Deliverable 4.1: Write a function to calculate the number of features whose weights are nonzero when using L1 regularization. Calculate the number of nonzero feature weights when `alpha` is one of $[0.00001, 0.0001, 0.001, 0.01, 0.1]$. Create a plot where the x-axis is `alpha` and the y-axis is the number of nonzero weights, using a log scale for the x-axis.
#
# [your solution should be plotted below]

# %%
# your code here
